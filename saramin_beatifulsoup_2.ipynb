# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
URL = 'https://www.saramin.co.kr/zf_user/jobs/list/job-category?cat_mcls=2&sort=RD'
I_URL = 'https://www.saramin.co.kr/zf_user/jobs/relay/view?'
LIMIT = 1

# %%
def extract_info(html):
    global LIMIT
    #inx
    idx = html['id'][4:]
    stacks = extract_stack(idx)
        #pages
    
    
    
    #회사명
    company = html.find("div",{"class":"company_nm"}).find("a").string
    #제목
    title = html.find("div",{"class":"job_tit"}).find("a").string
    #스택
    works = []

    work_s = html.find("span",{"class":"job_sector"}).find_all("span")#span값

    for work in work_s:
        works.append(work.string)

    #경력
    career = html.find("p",{"class":"career"}).string
    #학력
    education = html.find("p",{"class":"education"}).string
    #근무형태
    employment_t = html.find("p",{"class":"employment_type"}).string
    #근무장소
    try:
        place = html.find("p",{"class":"work_place"}).string
    except Exception as e:
        place = "None"
    #마감일
    lim = html.find("span",{"class":"reg_date"}).string
#	print(lim)
    #등록일
    if(lim == '(1일 전 등록)'):
        LIMIT = 0
        return stacks#[title,  company,  works,  career,  education,  employment_t,  place]

    return stacks#[title,  company,  works,  career,  education,  employment_t,  place]

# %%
def extract_page(last_p):#전체페이지
    result = requests.get(f"{URL}&page={last_p}")

    soup = BeautifulSoup(result.text, "html.parser")
    print(soup)
    infos= soup.find_all("div", {"class":"list_item"})
    
    jobs = []
    for info in infos:
        #job = extract_info(info)
        jobs.append(job)
	#	print(job)
	#	print("\n")

    return jobs

# %%
def main():
    global LIMIT
    a_jobs = []
    i = 1 
    while(LIMIT):
        a_jobs.extend(extract_page(i))
        i = i+1
        break
    return a_jobs

# %%
def extract_stack(id_num):#세부페이지
    D_URL = 'https://www.saramin.co.kr/zf_user/jobs/relay/view?rec_idx='+id_num

    result = requests.get(f"{D_URL}")

    soup = BeautifulSoup(result.text, "html.parser")
    print(soup)
    stacks = soup.find("div", {"class":"tags"})
    result = []
    #print(stacks)
    return result

#스크롤이 필요함

# %%
main()
# Out:
# <!DOCTYPE html>
# <html lang="ko">
# <head>
# <title>IT개발·데이터 취업 | 직업별 채용정보 - 사람인</title> <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# ...
