# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By

options = webdriver.ChromeOptions()
options.add_argument('headless')

URL = "https://www.saramin.co.kr/zf_user/jobs/list/job-category?cat_mcls=2&sort=RD&page=2"
browser = webdriver.Chrome("/usr/local/bin/chromedriver");	#chromedriver 위치

browser.get(URL);	# 페이지 열기

browser.implicitly_wait(2)
# Out:
# /var/folders/8l/z4qr6xns7sb_mbw_25xwx0cm0000gn/T/ipykernel_850/421424740.py:9: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   browser = webdriver.Chrome("/usr/local/bin/chromedriver");	#chromedriver 위치

# %%
def get_info():

    items = browser.find_elements(By.CSS_SELECTOR,'.list_item')
    ann_list = []
    for item in items:
        #id
        idx = item.get_attribute('id')[4:]
    
        # 회사
        company = item.find_element(By.CSS_SELECTOR,".company_nm").find_element(By.TAG_NAME, 'a').text
    
        # 제목
        title = item.find_element(By.CSS_SELECTOR,".notification_info").find_element(By.TAG_NAME, 'a').text
    
        # 경력
        career = item.find_element(By.CSS_SELECTOR,".career").text
    
        # 학력
        education = item.find_element(By.CSS_SELECTOR,".education").text
    
        # 근무형태
        employment_type = item.find_element(By.CSS_SELECTOR,".employment_type").text
    
        # 근무 위치
        work_place = item.find_element(By.CSS_SELECTOR,".work_place").text
    
        #마감일,등록일
        time = item.find_element(By.CSS_SELECTOR,".deadlines").text.split('\n')
        deadline = time[0]
        reg_date = time[1]
        info = {'company' : company, 'title' : title, 'stack': 0, 'career' : career, 
            'education' : education, 'em_type' : employment_type, 'work_place':work_place, 'deadeline' : deadline }
        ann_list.append(info)
        print(info, idx)
        print("\n")
    return ann_list

get_info()
# Out:
# {'company': '(주)엔엠에스컨설팅', 'title': '외국계 게임사 Game Platform QA (Junior) 모집', 'stack': 0, 'career': '1 ~ 5년', 'education': '대학교(4년)↑', 'em_type': '정규직', 'work_place': '서울 강남구', 'deadeline': '채용시'} 42284140
#
#
# {'company': '(주)엔엠에스컨설팅', 'title': '외국계 게임사 Server Programmer 모집', 'stack': 0, 'career': '경력 3년↑', 'education': '대학교(4년)↑', 'em_type': '정규직', 'work_place': '서울 강남구', 'deadeline': '채용시'} 42284133
#
#
# {'company': '이음소프트', 'title': 'Android & IOS 앱 개발자, JAVA/JSP/Spring/eGov 웹 개발자 경력직 모집', 'stack': 0, 'career': '신입 · 경력', 'education': '학력무관', 'em_type': '정규직', 'work_place': '대전 서구', 'deadeline': '~ 02/28(월)'} 42284117
#
#
# {'company': '(주)케이앤웍스', 'title': '[신입/경력] 카카오 커머스 모니터링/운영 관리/콘텐츠 제작 담당자 모집', 'stack': 0, 'career': '신입 · 경력', 'education': '학력무관', 'em_type': '계약직', 'work_place': '서울 금천구', 'deadeline': '~ 02/18(금)'} 42284111
#
#
# {'company': '(주)오렌지씨큐리티', 'title': '해사 사이버보안 컨설턴트 모집 (항해, 기관)', 'stack': 0, 'career': '경력무관', 'education': '대학교(4년)↑', 'em_type': '정규직', 'work_place': '서울 강남구', 'deadeline': '상시채용'} 42284085
#
#
# {'company': '브레인즈컴퍼니(주)', 'title': '웹 개발(5년이상, Java, JavaScript, SQL)', 'stack': 0, 'career': '5 ~ 15년', 'education': '대학교(4년)↑', 'em_type': '정규직', 'work_place': '서울전체', 'deadeline': '~ 02/22(화)'} 42284084
#
#
# {'company': '(주)유앤파트너즈', 'title': '외국계 기업 - 애플리케이션 엔지니어 (신입 / 경력)', 'stack': 0, 'career': '경력무관', 'education': '대학교(4년)↑', 'em_type': '정규직', 'work_place': '경기 성남시 분당구', 'deadeline': '~ 02/24(목)'} 42284024
#
#
# {'company': '(주)디이노', 'title': '[디이노] 웹 프론트엔드 개발자 채용', 'stack': 0, 'career': '경력 3년↑', 'education': '대학(2,3년)↑', 'em_type': '정규직', 'work_place': '대구 수성구', 'deadeline': '~ 03/11(금)'} 42283989
#
#
# {'company': '(주)스튜디오질풍', 'title': '[스튜디오질풍/광주] 웹UI디자인 / 웹기획 / 웹PD / 웹MD 모집', 'stack': 0, 'career': '경력무관', 'education': '학력무관', 'em_type': '정규직', 'work_place': '광주 광산구', 'deadeline': '상시채용'} 42283988
#
#
# {'company': '반석써치(주)', 'title': '프론트엔드 개발자 -소프트웨어 개발및 공급기업', 'stack': 0, 'career': '5 ~ 10년', 'education': '대학교(4년)↑', 'em_type': '정규직', 'work_place': '서울 중구', 'deadeline': '~ 02/21(월)'} 42283984
#
#
# {'company': '셀빅', 'title': '[각 분야별] IT 보안 및 네트워크 정규직 모집합니다', 'stack': 0, 'career': '3 ~ 15년', 'education': '학력무관', 'em_type': '정규직', 'work_place': '서울 성동구', 'deadeline': '~ 03/11(금)'} 42283983
#
#
# {'company': '(주)스튜디오질풍', 'title': '[스튜디오질풍/광주] 웹개발자 모집', 'stack': 0, 'career': '경력무관', 'education': '학력무관', 'em_type': '정규직', 'work_place': '광주 광산구', 'deadeline': '상시채용'} 42283934
#
#
# {'company': '(주)제너시스템', 'title': '전산장비 유지보수 [성남지역/서울지역]', 'stack': 0, 'career': '신입', 'education': '고졸↑', 'em_type': '정규직', 'work_place': '경기 성남시 수정구', 'deadeline': '~ 03/11(금)'} 42283914
#
#
# {'company': '(주)퍼플소프트', 'title': '개발팀 SW(소프트웨어) 경력무관 모집 공고', 'stack': 0, 'career': '경력무관', 'education': '학력무관', 'em_type': '정규직', 'work_place': '대구 달서구', 'deadeline': '~ 04/10(일)'} 42283866
#
#
# {'company': '시그네틱스(주)', 'title': '정보기술팀 /신입/ 채용', 'stack': 0, 'career': '경력무관', 'education': '대학교(4년)↑', 'em_type': '정규직', 'work_place': '경기 파주시', 'deadeline': '~ 03/11(금)'} 42283862
#
#
# {'company': '(주)디케이테크인', 'title': '[카카오자회사] 서비스 운영 시스템 개발자 모집(제주근무)', 'stack': 0, 'career': '1 ~ 4년', 'education': '학력무관', 'em_type': '정규직', 'work_place': '제주 제주시', 'deadeline': '~ 02/28(월)'} 42283799
#
#
# {'company': '㈜지오투정보기술', 'title': '웹 어플리케이션유지보수 개발자 신입 및 경력직 채용', 'stack': 0, 'career': '신입 · 경력', 'education': '대학(2,3년)↑', 'em_type': '정규직', 'work_place': '경기 안양시 동안구', 'deadeline': '~ 03/11(금)'} 42283757
#
#
# {'company': '(주)아로아소프트', 'title': '보안 솔루션 영업 인원 채용', 'stack': 0, 'career': '경력무관', 'education': '학력무관', 'em_type': '정규직', 'work_place': '서울 강남구', 'deadeline': '~ 03/11(금)'} 42283747
#
#
# {'company': '조인어스비즈(주)', 'title': '조인어스비즈(주) 클라우드 보안사업부 엔지니어 모집(신입/경력', 'stack': 0, 'career': '신입 · 경력', 'education': '대학(2,3년)↑', 'em_type': '정규직', 'work_place': '서울 마포구', 'deadeline': '~ 04/10(일)'} 42283745
#
#
# {'company': '주식회사 페이로', 'title': 'VAN 결제 안드로이드 POS 영업관리', 'stack': 0, 'career': '경력무관', 'education': '대학(2,3년)↑', 'em_type': '정규직', 'work_place': '서울 중구', 'deadeline': '~ 03/11(금)'} 42283740
#
#
# {'company': '주식회사 에스비컴퍼니코리아', 'title': 'NFT 커뮤니티 & PFP NFT 개발', 'stack': 0, 'career': '경력무관', 'education': '학력무관', 'em_type': '정규직', 'work_place': '서울 송파구', 'deadeline': '~ 03/11(금)'} 42283726
#
#
# {'company': '(주)엔토포스', 'title': '[GIS]2022년 (주)엔토포스 신입,경력 사원 채용', 'stack': 0, 'career': '경력무관', 'education': '학력무관', 'em_type': '정규직', 'work_place': '경기 안양시 동안구', 'deadeline': '~ 03/11(금)'} 42283722
#
#
# {'company': '(주)디텍그룹', 'title': '[통신파트] LG U+biz 개통실 정규직 채용 공고(경력)', 'stack': 0, 'career': '경력 1년↑', 'education': '학력무관', 'em_type': '정규직', 'work_place': '서울 강서구', 'deadeline': '~ 03/11(금)'} 42283687
#
#
# {'company': '(주)디에스엘', 'title': '웹디자인 경력자 모집 (오픈마켓,쇼설,종합몰 웹디자이너)', 'stack': 0, 'career': '경력무관', 'education': '학력무관', 'em_type': '정규직', 'work_place': '경기 하남시', 'deadeline': '~ 02/20(일)'} 42283658
#
#
# {'company': '(주)헤더라임', 'title': '웹 프로그램 개발자 경력&신입 채용 - 정규직/계약직', 'stack': 0, 'career': '신입 · 경력', 'education': '고졸↑', 'em_type': '정규직 · 계약직', 'work_place': '인천 서구', 'deadeline': '~ 03/11(금)'} 42283646
#
#
# {'company': '(주)이테크시스템', 'title': '시스템 엔지니어 경력 채용', 'stack': 0, 'career': '경력무관', 'education': '학력무관', 'em_type': '정규직', 'work_place': '서울 중구', 'deadeline': '~ 03/11(금)'} 42283617
#
#
# {'company': '(주)제이앤씨에이치알', 'title': 'Back-end 개발자 - 글로벌 자동차 부품 그룹 관계사', 'stack': 0, 'career': '경력 4년↑', 'education': '대학교(4년)↑', 'em_type': '정규직', 'work_place': '부산 해운대구', 'deadeline': '채용시'} 42283616
#
#
# {'company': '(주)제이앤씨에이치알', 'title': '의료 데이터사이언스 - IPO 준비 의료 빅데이터 IT기업', 'stack': 0, 'career': '2 ~ 8년', 'education': '대학교(4년)↑', 'em_type': '정규직', 'work_place': '경기 성남시 분당구', 'deadeline': '채용시'} 42283598
#
#
# {'company': '서비스테크', 'title': '관공서 전산장비 유지보수 서비스 업무', 'stack': 0, 'career': '신입 · 경력', 'education': '학력무관', 'em_type': '정규직', 'work_place': '경북 경주시', 'deadeline': '~ 03/11(금)'} 42283594
#
#
# {'company': '(주)제이앤씨에이치알', 'title': '데이터솔루션 - IPO 준비 의료 빅데이터 IT기업', 'stack': 0, 'career': '2 ~ 11년', 'education': '대학교(4년)↑', 'em_type': '정규직', 'work_place': '경기 성남시 분당구', 'deadeline': '채용시'} 42283590
#
#
# {'company': '(주)링캠', 'title': '[링캠] 서버·네트워크·보안 신입/경력직 엔지니어 모집합니다.', 'stack': 0, 'career': '경력무관', 'education': '대학(2,3년)↑', 'em_type': '정규직', 'work_place': '대전 유성구', 'deadeline': '~ 04/10(일)'} 42283573
#
#
# {'company': '(주)제이앤씨에이치알', 'title': 'Front-end (F/E) 개발자 - IPO 준비 의료 빅데이터 IT기업', 'stack': 0, 'career': '3 ~ 15년', 'education': '대학교(4년)↑', 'em_type': '정규직', 'work_place': '서울 서초구', 'deadeline': '~ 03/11(금)'} 42283469
#
#
# {'company': '(주)제이앤씨에이치알', 'title': 'Back-end (B/E) 개발자 - IPO 준비 의료 빅데이터 IT기업', 'stack': 0, 'career': '3 ~ 15년', 'education': '대학교(4년)↑', 'em_type': '정규직', 'work_place': '서울 서초구', 'deadeline': '~ 03/11(금)'} 42283456
#
#
# {'company': '(주)제이앤씨에이치알', 'title': '플랫폼 Back-end (B/E) 개발자 - IPO준비 의료 빅데이터 IT기업', 'stack': 0, 'career': '3 ~ 15년', 'education': '대학교(4년)↑', 'em_type': '정규직', 'work_place': '서울 서초구', 'deadeline': '~ 03/11(금)'} 42283440
#
#
# {'company': '제이케이서치 주식회사', 'title': '유명 글로벌 바이오 중견기업 IT Business Analyst', 'stack': 0, 'career': '경력 8년↑', 'education': '대학교(4년)↑', 'em_type': '정규직', 'work_place': '경기 용인시 기흥구', 'deadeline': '~ 03/11(금)'} 42283429
#
#
# {'company': '(주)비카누스', 'title': '소프트웨어 분야별 채용 (백/프론트엔드, AR/VR SW)', 'stack': 0, 'career': '경력무관', 'education': '학력무관', 'em_type': '정규직 · 계약직', 'work_place': '경기 성남시 분당구', 'deadeline': '~ 03/11(금)'} 42283396
#
#
# {'company': '(주)스피링크', 'title': '인공지능(AI) 학습용 상담 데이터 구축(재택 / 3주)', 'stack': 0, 'career': '경력무관', 'education': '학력무관', 'em_type': '프리랜서', 'work_place': '서울 용산구', 'deadeline': '~ 02/18(금)'} 42283371
#
#
# {'company': '(주)예스히팅테크닉스', 'title': 'set-up 및 유지보수 사원 모집 (정규직)', 'stack': 0, 'career': '경력무관', 'education': '학력무관', 'em_type': '정규직', 'work_place': '경기 평택시', 'deadeline': '~ 03/11(금)'} 42283361
#
#
# {'company': '(주)벨아이앤에스', 'title': '[종근당 계열사] WEBㆍAPP 기획/JAVA개발자 및 APP/WEB 디자이너 채용', 'stack': 0, 'career': '신입 · 경력', 'education': '학력무관', 'em_type': '정규직', 'work_place': '서울 서대문구', 'deadeline': '~ 02/18(금)'} 42283352
#
#
# {'company': '(주)티오에스코리아', 'title': '[대기업/신입가능/시청] 본사 내 IT 기술지원 B2B 헬프데스크', 'stack': 0, 'career': '경력무관', 'education': '대학(2,3년)↑', 'em_type': '계약직 · 파견직', 'work_place': '서울 중구', 'deadeline': '~ 03/11(금)'} 42283341
#
#
# {'company': '(주)토비스', 'title': '경력직(의료 모니터 FW 개발자, 개발 PM, 기술 Coordinator)', 'stack': 0, 'career': '경력 5년↑', 'education': '대학(2,3년)↑', 'em_type': '정규직', 'work_place': '인천 연수구', 'deadeline': '~ 03/11(금)'} 42283332
#
#
# {'company': '외꾸나피싱 (더플러스조구)', 'title': '망미역(확장 이전) 쇼핑몰관련업무, 디자이너 충원(포토샵 일러', 'stack': 0, 'career': '경력무관', 'education': '대학(2,3년)↑', 'em_type': '정규직', 'work_place': '부산 수영구', 'deadeline': '채용시'} 42283328
# {'company': '제이케이서치 주식회사', 'title': '유명 바이오 중견기업 IT 담당 채용', 'stack': 0, 'career': '3 ~ 8년', 'education': '대학교(4년)↑', 'em_type': '정규직', 'work_place': '충북 청주시 흥덕구', 'deadeline': '~ 03/11(금)'} 42283318
#
#
# {'company': '(주)소프트넷', 'title': '2022년 IT기술연구소 자바개발자 경력직 채용공고', 'stack': 0, 'career': '3 ~ 10년', 'education': '대학(2,3년)↑', 'em_type': '정규직', 'work_place': '서울 강남구', 'deadeline': '~ 03/11(금)'} 42283316
#
#
# {'company': '(주)퍼지시스템', 'title': '3D CAD 기술부 인재를 모십니다.', 'stack': 0, 'career': '신입 · 경력', 'education': '대학(2,3년)↑', 'em_type': '정규직', 'work_place': '서울 금천구', 'deadeline': '~ 04/10(일)'} 42283310
#
#
# {'company': '코리아스펙트랄프로덕츠(주)', 'title': '부설연구소 연구원 채용', 'stack': 0, 'career': '경력무관', 'education': '대학(2,3년)↑', 'em_type': '정규직', 'work_place': '서울 구로구', 'deadeline': '~ 03/31(목)'} 42283251
#
#
# {'company': '한국클라우드컴퓨팅연구조합', 'title': '한국클라우드컴퓨팅연구조합 직원 채용(1차 모집)', 'stack': 0, 'career': '신입 · 경력', 'education': '대학(2,3년)↑', 'em_type': '정규직', 'work_place': '서울 강남구', 'deadeline': '~ 02/28(월)'} 42283237
#
#
# {'company': '제이케이서치 주식회사', 'title': '첨단 물류기업 IT 물류프로그램 개발/운영 담당자 채용', 'stack': 0, 'career': '3 ~ 9년', 'education': '대학(2,3년)↑', 'em_type': '정규직', 'work_place': '경기 평택시', 'deadeline': '~ 03/11(금)'} 42283224
#
#
# {'company': '(주)삼신', 'title': '정보관리실 ERP운영 및 유지보수 채용(경력&신입)', 'stack': 0, 'career': '신입 · 경력', 'education': '대학(2,3년)↑', 'em_type': '정규직', 'work_place': '충남 천안시 서북구', 'deadeline': '~ 04/10(일)'} 42283217
#
#
# {'company': '(사)와우책문화예술센터', 'title': '(사)와우책문화예술센터 2022년 상반기 채용공고', 'stack': 0, 'career': '경력무관', 'education': '대학(2,3년)↑', 'em_type': '정규직 · 계약직', 'work_place': '서울 마포구', 'deadeline': '채용시'} 42283198
# [{'company': '(주)엔엠에스컨설팅',
#   'title': '외국계 게임사 Game Platform QA (Junior) 모집',
#   'stack': 0,
#   'career': '1 ~ 5년',
#   'education': '대학교(4년)↑',
#   'em_type': '정규직',
#   'work_place': '서울 강남구',
#   'deadeline': '채용시'},
#  {'company': '(주)엔엠에스컨설팅',
#   'title': '외국계 게임사 Server Programmer 모집',
#   'stack': 0,
#   'career': '경력 3년↑',
#   'education': '대학교(4년)↑',
#   'em_type': '정규직',
#   'work_place': '서울 강남구',
#   'deadeline': '채용시'},
#  {'company': '이음소프트',
#   'title': 'Android & IOS 앱 개발자, JAVA/JSP/Spring/eGov 웹 개발자 경력직 모집',
#   'stack': 0,
#   'career': '신입 · 경력',
#   'education': '학력무관',
#   'em_type': '정규직',
#   'work_place': '대전 서구',
#   'deadeline': '~ 02/28(월)'},
#  {'company': '(주)케이앤웍스',
#   'title': '[신입/경력] 카카오 커머스 모니터링/운영 관리/콘텐츠 제작 담당자 모집',
#   'stack': 0,
#   'career': '신입 · 경력',
#   'education': '학력무관',
#   'em_type': '계약직',
#   'work_place': '서울 금천구',
#   'deadeline': '~ 02/18(금)'},
#  {'company': '(주)오렌지씨큐리티',
#   'title': '해사 사이버보안 컨설턴트 모집 (항해, 기관)',
#   'stack': 0,
#   'career': '경력무관',
#   'education': '대학교(4년)↑',
#   'em_type': '정규직',
#   'work_place': '서울 강남구',
#   'deadeline': '상시채용'},
#  {'company': '브레인즈컴퍼니(주)',
#   'title': '웹 개발(5년이상, Java, JavaScript, SQL)',
#   'stack': 0,
#   'career': '5 ~ 15년',
#   'education': '대학교(4년)↑',
#   'em_type': '정규직',
#   'work_place': '서울전체',
#   'deadeline': '~ 02/22(화)'},
#  {'company': '(주)유앤파트너즈',
#   'title': '외국계 기업 - 애플리케이션 엔지니어 (신입 / 경력)',
#   'stack': 0,
#   'career': '경력무관',
#   'education': '대학교(4년)↑',
#   'em_type': '정규직',
#   'work_place': '경기 성남시 분당구',
#   'deadeline': '~ 02/24(목)'},
#  {'company': '(주)디이노',
#   'title': '[디이노] 웹 프론트엔드 개발자 채용',
#   'stack': 0,
#   'career': '경력 3년↑',
#   'education': '대학(2,3년)↑',
#   'em_type': '정규직',
#   'work_place': '대구 수성구',
#   'deadeline': '~ 03/11(금)'},
#  {'company': '(주)스튜디오질풍',
#   'title': '[스튜디오질풍/광주] 웹UI디자인 / 웹기획 / 웹PD / 웹MD 모집',
#   'stack': 0,
#   'career': '경력무관',
#   'education': '학력무관',
#   'em_type': '정규직',
#   'work_place': '광주 광산구',
#   'deadeline': '상시채용'},
#  {'company': '반석써치(주)',
#   'title': '프론트엔드 개발자 -소프트웨어 개발및 공급기업',
#   'stack': 0,
#   'career': '5 ~ 10년',
#   'education': '대학교(4년)↑',
#   'em_type': '정규직',
#   'work_place': '서울 중구',
#   'deadeline': '~ 02/21(월)'},
#  {'company': '셀빅',
#   'title': '[각 분야별] IT 보안 및 네트워크 정규직 모집합니다',
#   'stack': 0,
#   'career': '3 ~ 15년',
#   'education': '학력무관',
#   'em_type': '정규직',
#   'work_place': '서울 성동구',
#   'deadeline': '~ 03/11(금)'},
#  {'company': '(주)스튜디오질풍',
#   'title': '[스튜디오질풍/광주] 웹개발자 모집',
#   'stack': 0,
#   'career': '경력무관',
#   'education': '학력무관',
#   'em_type': '정규직',
#   'work_place': '광주 광산구',
#   'deadeline': '상시채용'},
#  {'company': '(주)제너시스템',
#   'title': '전산장비 유지보수 [성남지역/서울지역]',
#   'stack': 0,
#   'career': '신입',
#   'education': '고졸↑',
#   'em_type': '정규직',
#   'work_place': '경기 성남시 수정구',
#   'deadeline': '~ 03/11(금)'},
#  {'company': '(주)퍼플소프트',
#   'title': '개발팀 SW(소프트웨어) 경력무관 모집 공고',
#   'stack': 0,
#   'career': '경력무관',
#   'education': '학력무관',
#   'em_type': '정규직',
#   'work_place': '대구 달서구',
#   'deadeline': '~ 04/10(일)'},
#  {'company': '시그네틱스(주)',
#   'title': '정보기술팀 /신입/ 채용',
#   'stack': 0,
#   'career': '경력무관',
#   'education': '대학교(4년)↑',
#   'em_type': '정규직',
#   'work_place': '경기 파주시',
#   'deadeline': '~ 03/11(금)'},
#  {'company': '(주)디케이테크인',
#   'title': '[카카오자회사] 서비스 운영 시스템 개발자 모집(제주근무)',
#   'stack': 0,
#   'career': '1 ~ 4년',
#   'education': '학력무관',
#   'em_type': '정규직',
#   'work_place': '제주 제주시',
#   'deadeline': '~ 02/28(월)'},
#  {'company': '㈜지오투정보기술',
#   'title': '웹 어플리케이션유지보수 개발자 신입 및 경력직 채용',
#   'stack': 0,
#   'career': '신입 · 경력',
#   'education': '대학(2,3년)↑',
#   'em_type': '정규직',
#   'work_place': '경기 안양시 동안구',
#   'deadeline': '~ 03/11(금)'},
#  {'company': '(주)아로아소프트',
#   'title': '보안 솔루션 영업 인원 채용',
#   'stack': 0,
#   'career': '경력무관',
#   'education': '학력무관',
#   'em_type': '정규직',
#   'work_place': '서울 강남구',
#   'deadeline': '~ 03/11(금)'},
#  {'company': '조인어스비즈(주)',
#   'title': '조인어스비즈(주) 클라우드 보안사업부 엔지니어 모집(신입/경력',
#   'stack': 0,
#   'career': '신입 · 경력',
#   'education': '대학(2,3년)↑',
#   'em_type': '정규직',
#   'work_place': '서울 마포구',
#   'deadeline': '~ 04/10(일)'},
#  {'company': '주식회사 페이로',
#   'title': 'VAN 결제 안드로이드 POS 영업관리',
#   'stack': 0,
#   'career': '경력무관',
#   'education': '대학(2,3년)↑',
#   'em_type': '정규직',
#   'work_place': '서울 중구',
#   'deadeline': '~ 03/11(금)'},
#  {'company': '주식회사 에스비컴퍼니코리아',
#   'title': 'NFT 커뮤니티 & PFP NFT 개발',
#   'stack': 0,
#   'career': '경력무관',
#   'education': '학력무관',
#   'em_type': '정규직',
#   'work_place': '서울 송파구',
#   'deadeline': '~ 03/11(금)'},
#  {'company': '(주)엔토포스',
#   'title': '[GIS]2022년 (주)엔토포스 신입,경력 사원 채용',
#   'stack': 0,
#   'career': '경력무관',
#   'education': '학력무관',
#   'em_type': '정규직',
#   'work_place': '경기 안양시 동안구',
#   'deadeline': '~ 03/11(금)'},
#  {'company': '(주)디텍그룹',
#   'title': '[통신파트] LG U+biz 개통실 정규직 채용 공고(경력)',
#   'stack': 0,
#   'career': '경력 1년↑',
#   'education': '학력무관',
#   'em_type': '정규직',
#   'work_place': '서울 강서구',
#   'deadeline': '~ 03/11(금)'},
#  {'company': '(주)디에스엘',
#   'title': '웹디자인 경력자 모집 (오픈마켓,쇼설,종합몰 웹디자이너)',
#   'stack': 0,
#   'career': '경력무관',
#   'education': '학력무관',
#   'em_type': '정규직',
#   'work_place': '경기 하남시',
#   'deadeline': '~ 02/20(일)'},
#  {'company': '(주)헤더라임',
#   'title': '웹 프로그램 개발자 경력&신입 채용 - 정규직/계약직',
#   'stack': 0,
#   'career': '신입 · 경력',
#   'education': '고졸↑',
#   'em_type': '정규직 · 계약직',
#   'work_place': '인천 서구',
#   'deadeline': '~ 03/11(금)'},
#  {'company': '(주)이테크시스템',
#   'title': '시스템 엔지니어 경력 채용',
#   'stack': 0,
#   'career': '경력무관',
#   'education': '학력무관',
#   'em_type': '정규직',
#   'work_place': '서울 중구',
#   'deadeline': '~ 03/11(금)'},
#  {'company': '(주)제이앤씨에이치알',
#   'title': 'Back-end 개발자 - 글로벌 자동차 부품 그룹 관계사',
#   'stack': 0,
#   'career': '경력 4년↑',
#   'education': '대학교(4년)↑',
#   'em_type': '정규직',
#   'work_place': '부산 해운대구',
#   'deadeline': '채용시'},
#  {'company': '(주)제이앤씨에이치알',
#   'title': '의료 데이터사이언스 - IPO 준비 의료 빅데이터 IT기업',
#   'stack': 0,
#   'career': '2 ~ 8년',
#   'education': '대학교(4년)↑',
#   'em_type': '정규직',
#   'work_place': '경기 성남시 분당구',
#   'deadeline': '채용시'},
#  {'company': '서비스테크',
#   'title': '관공서 전산장비 유지보수 서비스 업무',
#   'stack': 0,
#   'career': '신입 · 경력',
#   'education': '학력무관',
#   'em_type': '정규직',
#   'work_place': '경북 경주시',
#   'deadeline': '~ 03/11(금)'},
#  {'company': '(주)제이앤씨에이치알',
#   'title': '데이터솔루션 - IPO 준비 의료 빅데이터 IT기업',
#   'stack': 0,
#   'career': '2 ~ 11년',
#   'education': '대학교(4년)↑',
#   'em_type': '정규직',
#   'work_place': '경기 성남시 분당구',
#   'deadeline': '채용시'},
#  {'company': '(주)링캠',
#   'title': '[링캠] 서버·네트워크·보안 신입/경력직 엔지니어 모집합니다.',
#   'stack': 0,
#   'career': '경력무관',
#   'education': '대학(2,3년)↑',
#   'em_type': '정규직',
#   'work_place': '대전 유성구',
#   'deadeline': '~ 04/10(일)'},
#  {'company': '(주)제이앤씨에이치알',
#   'title': 'Front-end (F/E) 개발자 - IPO 준비 의료 빅데이터 IT기업',
#   'stack': 0,
#   'career': '3 ~ 15년',
#   'education': '대학교(4년)↑',
#   'em_type': '정규직',
#   'work_place': '서울 서초구',
#   'deadeline': '~ 03/11(금)'},
#  {'company': '(주)제이앤씨에이치알',
#   'title': 'Back-end (B/E) 개발자 - IPO 준비 의료 빅데이터 IT기업',
#   'stack': 0,
#   'career': '3 ~ 15년',
#   'education': '대학교(4년)↑',
#   'em_type': '정규직',
#   'work_place': '서울 서초구',
#   'deadeline': '~ 03/11(금)'},
#  {'company': '(주)제이앤씨에이치알',
#   'title': '플랫폼 Back-end (B/E) 개발자 - IPO준비 의료 빅데이터 IT기업',
#   'stack': 0,
#   'career': '3 ~ 15년',
#   'education': '대학교(4년)↑',
#   'em_type': '정규직',
#   'work_place': '서울 서초구',
#   'deadeline': '~ 03/11(금)'},
#  {'company': '제이케이서치 주식회사',
#   'title': '유명 글로벌 바이오 중견기업 IT Business Analyst',
#   'stack': 0,
#   'career': '경력 8년↑',
#   'education': '대학교(4년)↑',
#   'em_type': '정규직',
#   'work_place': '경기 용인시 기흥구',
#   'deadeline': '~ 03/11(금)'},
#  {'company': '(주)비카누스',
#   'title': '소프트웨어 분야별 채용 (백/프론트엔드, AR/VR SW)',
#   'stack': 0,
#   'career': '경력무관',
#   'education': '학력무관',
#   'em_type': '정규직 · 계약직',
#   'work_place': '경기 성남시 분당구',
#   'deadeline': '~ 03/11(금)'},
#  {'company': '(주)스피링크',
#   'title': '인공지능(AI) 학습용 상담 데이터 구축(재택 / 3주)',
#   'stack': 0,
#   'career': '경력무관',
#   'education': '학력무관',
#   'em_type': '프리랜서',
#   'work_place': '서울 용산구',
#   'deadeline': '~ 02/18(금)'},
#  {'company': '(주)예스히팅테크닉스',
#   'title': 'set-up 및 유지보수 사원 모집 (정규직)',
#   'stack': 0,
#   'career': '경력무관',
#   'education': '학력무관',
#   'em_type': '정규직',
#   'work_place': '경기 평택시',
#   'deadeline': '~ 03/11(금)'},
#  {'company': '(주)벨아이앤에스',
#   'title': '[종근당 계열사] WEBㆍAPP 기획/JAVA개발자 및 APP/WEB 디자이너 채용',
#   'stack': 0,
#   'career': '신입 · 경력',
#   'education': '학력무관',
#   'em_type': '정규직',
#   'work_place': '서울 서대문구',
#   'deadeline': '~ 02/18(금)'},
#  {'company': '(주)티오에스코리아',
#   'title': '[대기업/신입가능/시청] 본사 내 IT 기술지원 B2B 헬프데스크',
#   'stack': 0,
#   'career': '경력무관',
#   'education': '대학(2,3년)↑',
#   'em_type': '계약직 · 파견직',
#   'work_place': '서울 중구',
#   'deadeline': '~ 03/11(금)'},
#  {'company': '(주)토비스',
#   'title': '경력직(의료 모니터 FW 개발자, 개발 PM, 기술 Coordinator)',
#   'stack': 0,
#   'career': '경력 5년↑',
#   'education': '대학(2,3년)↑',
#   'em_type': '정규직',
#   'work_place': '인천 연수구',
#   'deadeline': '~ 03/11(금)'},
#  {'company': '외꾸나피싱 (더플러스조구)',
#   'title': '망미역(확장 이전) 쇼핑몰관련업무, 디자이너 충원(포토샵 일러',
#   'stack': 0,
#   'career': '경력무관',
#   'education': '대학(2,3년)↑',
#   'em_type': '정규직',
#   'work_place': '부산 수영구',
#   'deadeline': '채용시'},
#  {'company': '제이케이서치 주식회사',
#   'title': '유명 바이오 중견기업 IT 담당 채용',
#   'stack': 0,
#   'career': '3 ~ 8년',
#   'education': '대학교(4년)↑',
#   'em_type': '정규직',
#   'work_place': '충북 청주시 흥덕구',
#   'deadeline': '~ 03/11(금)'},
#  {'company': '(주)소프트넷',
#   'title': '2022년 IT기술연구소 자바개발자 경력직 채용공고',
#   'stack': 0,
#   'career': '3 ~ 10년',
#   'education': '대학(2,3년)↑',
#   'em_type': '정규직',
#   'work_place': '서울 강남구',
#   'deadeline': '~ 03/11(금)'},
#  {'company': '(주)퍼지시스템',
#   'title': '3D CAD 기술부 인재를 모십니다.',
#   'stack': 0,
#   'career': '신입 · 경력',
#   'education': '대학(2,3년)↑',
#   'em_type': '정규직',
#   'work_place': '서울 금천구',
#   'deadeline': '~ 04/10(일)'},
#  {'company': '코리아스펙트랄프로덕츠(주)',
#   'title': '부설연구소 연구원 채용',
#   'stack': 0,
#   'career': '경력무관',
#   'education': '대학(2,3년)↑',
#   'em_type': '정규직',
#   'work_place': '서울 구로구',
#   'deadeline': '~ 03/31(목)'},
#  {'company': '한국클라우드컴퓨팅연구조합',
#   'title': '한국클라우드컴퓨팅연구조합 직원 채용(1차 모집)',
#   'stack': 0,
#   'career': '신입 · 경력',
#   'education': '대학(2,3년)↑',
#   'em_type': '정규직',
#   'work_place': '서울 강남구',
#   'deadeline': '~ 02/28(월)'},
#  {'company': '제이케이서치 주식회사',
#   'title': '첨단 물류기업 IT 물류프로그램 개발/운영 담당자 채용',
#   'stack': 0,
#   'career': '3 ~ 9년',
#   'education': '대학(2,3년)↑',
#   'em_type': '정규직',
#   'work_place': '경기 평택시',
#   'deadeline': '~ 03/11(금)'},
#  {'company': '(주)삼신',
#   'title': '정보관리실 ERP운영 및 유지보수 채용(경력&신입)',
#   'stack': 0,
#   'career': '신입 · 경력',
#   'education': '대학(2,3년)↑',
#   'em_type': '정규직',
#   'work_place': '충남 천안시 서북구',
#   'deadeline': '~ 04/10(일)'},
#  {'company': '(사)와우책문화예술센터',
#   'title': '(사)와우책문화예술센터 2022년 상반기 채용공고',
#   'stack': 0,
#   'career': '경력무관',
#   'education': '대학(2,3년)↑',
#   'em_type': '정규직 · 계약직',
#   'work_place': '서울 마포구',
#   'deadeline': '채용시'}]
