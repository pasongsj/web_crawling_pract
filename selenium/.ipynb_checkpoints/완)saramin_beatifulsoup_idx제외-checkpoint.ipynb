# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
URL = 'https://www.saramin.co.kr/zf_user/jobs/list/job-category?cat_mcls=2&sort=RD'
I_URL = 'https://www.saramin.co.kr/zf_user/jobs/relay/view?'
LIMIT = 1

# %%
def extract_info(html):
    global LIMIT
    #inx
    idx = html['id'][4:]
   # stacks = extract_stack(idx)
        #pages
    
    
    
    #회사명
    company = html.find("div",{"class":"company_nm"}).find("a").string
    #제목
    title = html.find("div",{"class":"job_tit"}).find("a").string
    #스택
    works = []

    work_s = html.find("span",{"class":"job_sector"}).find_all("span")#span값

    for work in work_s:
        works.append(work.string)

    #경력
    career = html.find("p",{"class":"career"}).string
    #학력
    education = html.find("p",{"class":"education"}).string
    #근무형태
    employment_t = html.find("p",{"class":"employment_type"}).string
    #근무장소
    try:
        place = html.find("p",{"class":"work_place"}).string
    except Exception as e:
        place = "None"
    #마감일
    deadline_tmp = html.find("p",{"class": "deadlines"}).get_text()
    deadlines = deadline_tmp[:deadline_tmp.find('(')]

    #등록일
    reg = html.find("span",{"class":"reg_date"}).string
    
    all_infos = {'title':title, 'company':company, 'career':career, 'education':education,
                'employment_type' :employment_t,  'workc_place':place, 'deadline': deadlines,
                'idx':idx,'reg':reg}
    if(reg == '(1일 전 등록)'):
        LIMIT = 0
        return all_infos
    return all_infos

# %%
def extract_page(last_p):#전체페이지
    result = requests.get(f"{URL}&page={last_p}")

    soup = BeautifulSoup(result.text, "html.parser")
    #print(soup)
    infos= soup.find_all("div", {"class":"list_item"})
    
    jobs = []
    for info in infos:
        job = extract_info(info)
        jobs.append(job)
        if(LIMIT == 0):
            return jobs
	#	print(job)
	#	print("\n")

    return jobs

# %%
def main():
    global LIMIT
    a_jobs = []
    i = 1
    while(LIMIT):
        a_jobs.extend(extract_page(i))
        i = i+1
        
    return a_jobs

# %%
data = main()

# %%
data#pd.DataFrame(data)
# Out:
# [{'title': '[O2pluss] AOS 개발자',
#   'company': '(주)오투플러스',
#   'career': '3 ~ 10년',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '경기전체',
#   'deadline': '상시채용',
#   'idx': '42297836',
#   'reg': '(15분 전 등록)'},
#  {'title': '[O2pluss] 웹개발 프론트엔드 개발자',
#   'company': '(주)오투플러스',
#   'career': '3 ~ 10년',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '경기전체',
#   'deadline': '상시채용',
#   'idx': '42297820',
#   'reg': '(16분 전 등록)'},
#  {'title': '[O2pluss] 웹개발 Back-end 개발자',
#   'company': '(주)오투플러스',
#   'career': '3 ~ 10년',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '경기전체',
#   'deadline': '상시채용',
#   'idx': '42297790',
#   'reg': '(18분 전 등록)'},
#  {'title': '모바일 백엔드 개발자 (3년 이상)',
#   'company': '(주)닥터다이어리',
#   'career': '3 ~ 10년',
#   'education': '대학교(4년)↑',
#   'employment_type': '정규직',
#   'workc_place': '서울전체',
#   'deadline': '상시채용',
#   'idx': '42297740',
#   'reg': '(22분 전 등록)'},
#  {'title': 'QA/테스터 계약직 채용(신입사원)',
#   'company': '(주)큐아이즈',
#   'career': '신입',
#   'education': '대학(2,3년)↑',
#   'employment_type': '계약직',
#   'workc_place': '서울 서초구',
#   'deadline': '채용시',
#   'idx': '42297718',
#   'reg': '(24분 전 등록)'},
#  {'title': 'Android 앱개발자 채용(경력 2년이상)',
#   'company': '레이드',
#   'career': '경력 2년↑',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '서울 송파구',
#   'deadline': '~ 04/11',
#   'idx': '42297594',
#   'reg': '(29분 전 등록)'},
#  {'title': '메타버스팀 AI 개발자',
#   'company': '(주)솔릭',
#   'career': '2 ~ 5년',
#   'education': '고졸↑',
#   'employment_type': '정규직',
#   'workc_place': '충북전체',
#   'deadline': '~ 03/31',
#   'idx': '42297542',
#   'reg': '(32분 전 등록)'},
#  {'title': '[정규직] 전산담당자 채용',
#   'company': '(주)윌비에스엔티',
#   'career': '2 ~ 10년',
#   'education': '대학(2,3년)↑',
#   'employment_type': '정규직',
#   'workc_place': '경기 화성시',
#   'deadline': '~ 03/12',
#   'idx': '42297483',
#   'reg': '(35분 전 등록)'},
#  {'title': '[성남본사] 클라우드 엔지니어로 성장할 여러분을 모십니다',
#   'company': '(주)홍익과학기술',
#   'career': '신입 · 경력',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '경기 성남시 수정구',
#   'deadline': '~ 03/12',
#   'idx': '42297479',
#   'reg': '(35분 전 등록)'},
#  {'title': '메타버스팀 VR/AR 개발자',
#   'company': '(주)솔릭',
#   'career': '2 ~ 5년',
#   'education': '고졸↑',
#   'employment_type': '정규직',
#   'workc_place': '충북전체',
#   'deadline': '~ 03/31',
#   'idx': '42297476',
#   'reg': '(35분 전 등록)'},
#  {'title': '[대기업/그룹사]Solutions Architect(네트워크)/대리-차장급',
#   'company': '㈜피플스카우트',
#   'career': '3 ~ 15년',
#   'education': '대학교(4년)↑',
#   'employment_type': '정규직 · 파견직',
#   'workc_place': '서울 구로구',
#   'deadline': '채용시',
#   'idx': '42297464',
#   'reg': '(36분 전 등록)'},
#  {'title': '[병원 모바일 서비스] 모바일 개발자 모집',
#   'company': '(주)포씨게이트',
#   'career': '경력 1년↑',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '서울 영등포구',
#   'deadline': '채용시',
#   'idx': '42297456',
#   'reg': '(36분 전 등록)'},
#  {'title': '프론트엔드 개발자 채용',
#   'company': '집닥(주)',
#   'career': '5 ~ 10년',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '서울전체',
#   'deadline': '상시채용',
#   'idx': '42297418',
#   'reg': '(39분 전 등록)'},
#  {'title': '자동차부품1차사 MES팀 (서버관리 外) 신입 채용',
#   'company': '코리아에프티(주)',
#   'career': '신입',
#   'education': '대학교(4년)↑',
#   'employment_type': '정규직',
#   'workc_place': '경기 안성시',
#   'deadline': '~ 03/12',
#   'idx': '42297414',
#   'reg': '(40분 전 등록)'},
#  {'title': "[미국취업] Sulsung Foods(Kim'c Market) : 소프트웨어 엔지니어",
#   'company': '(주)아이씨엔그룹',
#   'career': '2 ~ 5년',
#   'education': '대학(2,3년)↑',
#   'employment_type': '정규직 · 인턴직',
#   'workc_place': '북·중미 미국',
#   'deadline': '채용시',
#   'idx': '42297408',
#   'reg': '(40분 전 등록)'},
#  {'title': '앱개발자(Android/IOS) 경력 모집',
#   'company': '딱플(주)',
#   'career': '경력 3년↑',
#   'education': '대학(2,3년)↑',
#   'employment_type': '정규직',
#   'workc_place': '대전 유성구',
#   'deadline': '~ 03/12',
#   'idx': '42297331',
#   'reg': '(45분 전 등록)'},
#  {'title': '로봇 엔지니어링 & 소프트웨어 개발자 정규직 모집',
#   'company': '(주)힐스엔지니어링',
#   'career': '신입 · 경력',
#   'education': '대학교(4년)↑',
#   'employment_type': '정규직',
#   'workc_place': '경기 성남시 분당구',
#   'deadline': '~ 03/12',
#   'idx': '42297324',
#   'reg': '(45분 전 등록)'},
#  {'title': 'Linux 시스템 운영 관리자 모집합니다',
#   'company': '(주)소나텍',
#   'career': '경력 1년↑',
#   'education': '대학(2,3년)↑',
#   'employment_type': '정규직 · 계약직',
#   'workc_place': '서울 관악구',
#   'deadline': '~ 02/21',
#   'idx': '42297259',
#   'reg': '(50분 전 등록)'},
#  {'title': '서버 프로그래머/웹개발자(PHP)/ 클라이언트 개발자 채용',
#   'company': '주식회사 셰어링소프트',
#   'career': '경력무관',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '서울 강남구',
#   'deadline': '~ 03/12',
#   'idx': '42297206',
#   'reg': '(53분 전 등록)'},
#  {'title': '평행공간과 함께 하실 개발팀 리더를 모집합니다.',
#   'company': '(주)평행공간',
#   'career': '10 ~ 20년',
#   'education': '대학교(4년)↑',
#   'employment_type': '정규직',
#   'workc_place': '서울전체',
#   'deadline': '상시채용',
#   'idx': '42297197',
#   'reg': '(53분 전 등록)'},
#  {'title': '외국계 솔루션 기업 e-Commerce Hybris Solution Lead',
#   'company': '솔루션 인코퍼레이티드',
#   'career': '7 ~ 20년',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '서울 강남구',
#   'deadline': '채용시',
#   'idx': '42297194',
#   'reg': '(54분 전 등록)'},
#  {'title': 'CISCO 네트워크 운영자 모집합니다.',
#   'company': '(주)소나텍',
#   'career': '경력 2년↑',
#   'education': '대학(2,3년)↑',
#   'employment_type': '정규직',
#   'workc_place': '서울 성동구',
#   'deadline': '~ 02/21',
#   'idx': '42297187',
#   'reg': '(54분 전 등록)'},
#  {'title': '컴퓨터 및 운영시스템 유지보수 직원 채용',
#   'company': '㈜오경컴텍',
#   'career': '신입 · 경력',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '인천 연수구',
#   'deadline': '~ 03/12',
#   'idx': '42297171',
#   'reg': '(55분 전 등록)'},
#  {'title': '골프 하이브리드 앱 개발자 채용',
#   'company': '(주)그린재킷',
#   'career': '경력 2년↑',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '서울 서초구',
#   'deadline': '상시채용',
#   'idx': '42297083',
#   'reg': '(1시간 전 등록)'},
#  {'title': '디지털 퍼포먼스 마케터  경력 채용',
#   'company': '(주)보라공사',
#   'career': '신입 · 경력',
#   'education': '학력무관',
#   'employment_type': '정규직 · 계약직',
#   'workc_place': '부산 남구',
#   'deadline': '~ 03/12',
#   'idx': '42297065',
#   'reg': '(1시간 전 등록)'},
#  {'title': '[프레스토솔루션] Active Isolator Application 개발 엔지니어',
#   'company': '(주)프레스토솔루션',
#   'career': '경력무관',
#   'education': '대학교(4년)↑',
#   'employment_type': '정규직 · 계약직',
#   'workc_place': '경기 수원시 영통구',
#   'deadline': '~ 04/11',
#   'idx': '42297044',
#   'reg': '(1시간 전 등록)'},
#  {'title': 'IT Specialist -외국계 (Overseas Company)',
#   'company': '(주)아데코코리아',
#   'career': '5 ~ 10년',
#   'education': '대학교(4년)↑',
#   'employment_type': '정규직',
#   'workc_place': '서울 영등포구',
#   'deadline': '~ 02/21',
#   'idx': '42297025',
#   'reg': '(1시간 전 등록)'},
#  {'title': '콘텐츠 마케터  채용',
#   'company': '(주)보라공사',
#   'career': '경력 3년↑',
#   'education': '학력무관',
#   'employment_type': '정규직 · 계약직',
#   'workc_place': '부산 남구',
#   'deadline': '~ 03/12',
#   'idx': '42297006',
#   'reg': '(1시간 전 등록)'},
#  {'title': '웹 및 앱 개발자 경력/신입 채용 공고',
#   'company': '하이데브(HighDev)',
#   'career': '신입 · 경력',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '부산 부산진구',
#   'deadline': '상시채용',
#   'idx': '42297003',
#   'reg': '(1시간 전 등록)'},
#  {'title': '[펀익스] 웹 및 모바일 개발자, 웹기획 신입 및 경력 모집',
#   'company': '(주)펀익스',
#   'career': '신입 · 경력',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '경기 파주시',
#   'deadline': '~ 03/12',
#   'idx': '42296995',
#   'reg': '(1시간 전 등록)'},
#  {'title': '모바일(android, ios), 및 웹 개발자 채용 경력',
#   'company': '(주)보라공사',
#   'career': '경력 3년↑',
#   'education': '학력무관',
#   'employment_type': '정규직 · 계약직',
#   'workc_place': '부산 남구',
#   'deadline': '~ 03/12',
#   'idx': '42296967',
#   'reg': '(1시간 전 등록)'},
#  {'title': 'ITS장비(무인교통단속장비, CCTV) 설치 및 유지관리(기숙사제공)',
#   'company': '(주)유니시큐',
#   'career': '경력무관',
#   'education': '대학(2,3년)↑',
#   'employment_type': '정규직',
#   'workc_place': '경남 김해시',
#   'deadline': '~ 03/12',
#   'idx': '42296945',
#   'reg': '(1시간 전 등록)'},
#  {'title': 'PC 유지보수 경력직 직원모집3',
#   'company': '코스콤넷(주)',
#   'career': '2 ~ 6년',
#   'education': '대학(2,3년)↑',
#   'employment_type': '정규직 · 파견직',
#   'workc_place': '서울 동작구',
#   'deadline': '~ 04/11',
#   'idx': '42296928',
#   'reg': '(1시간 전 등록)'},
#  {'title': '응용프로그램/웹/데이터베이스 개발자',
#   'company': '(주)인브레인',
#   'career': '신입 · 경력',
#   'education': '대학(2,3년)↑',
#   'employment_type': '정규직',
#   'workc_place': '서울 금천구',
#   'deadline': '~ 04/11',
#   'idx': '42296926',
#   'reg': '(1시간 전 등록)'},
#  {'title': '[Iyuno-SDI Group] Data I/O Technician (데이터 I/O 담당자)',
#   'company': '(주)아이유노글로벌',
#   'career': '신입',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '서울 마포구',
#   'deadline': '~ 03/08',
#   'idx': '42296875',
#   'reg': '(1시간 전 등록)'},
#  {'title': '[성동구/정규직전환] 유명기업 PC전산총무 채용',
#   'company': '(주)키스템프',
#   'career': '경력 1년↑',
#   'education': '고졸↑',
#   'employment_type': '계약직 · 파견직',
#   'workc_place': '서울 성동구',
#   'deadline': '~ 02/15',
#   'idx': '42296804',
#   'reg': '(1시간 전 등록)'},
#  {'title': 'Altium Designer FAE 채용',
#   'company': '(주)한컴인텔리전스',
#   'career': '경력 3년↑',
#   'education': '대학교(4년)↑',
#   'employment_type': '정규직',
#   'workc_place': '경기 성남시 분당구',
#   'deadline': '채용시',
#   'idx': '42296797',
#   'reg': '(1시간 전 등록)'},
#  {'title': '렌터카 사업부 상반기 [신입/경력] 직원 공개 채용',
#   'company': '(주)우신오토파트너스',
#   'career': '신입 · 경력',
#   'education': '대학(2,3년)↑',
#   'employment_type': '정규직',
#   'workc_place': '서울 서초구',
#   'deadline': '~ 03/12',
#   'idx': '42296781',
#   'reg': '(1시간 전 등록)'},
#  {'title': '[ICT융합사업부] 정보보호 시스템 및 H/W 엔지니어 모집',
#   'company': '(주)아리네트웍스',
#   'career': '신입 · 경력',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '서울 성동구',
#   'deadline': '~ 03/12',
#   'idx': '42296774',
#   'reg': '(1시간 전 등록)'},
#  {'title': 'SK텔레콤 충북Access Infra팀 품질측정 단기계약직 채용',
#   'company': 'SK텔레콤(주)',
#   'career': '경력무관',
#   'education': '대학(2,3년)↑',
#   'employment_type': '계약직 · 아르바이트',
#   'workc_place': '충북 청주시 서원구',
#   'deadline': '~ 03/12',
#   'idx': '42296772',
#   'reg': '(1시간 전 등록)'},
#  {'title': '나이스신용평가 IT개발 담당자 경력 채용',
#   'company': '나이스신용평가(주)',
#   'career': '경력 5년↑',
#   'education': '대학교(4년)↑',
#   'employment_type': '계약직',
#   'workc_place': '서울 영등포구',
#   'deadline': '~ 02/27',
#   'idx': '42296767',
#   'reg': '(1시간 전 등록)'},
#  {'title': '레이저응용공법 및 장비개발자-공정, 소프트웨어, 기계설계',
#   'company': '(주)레이저앱스',
#   'career': '경력무관',
#   'education': '대학(2,3년)↑',
#   'employment_type': '정규직',
#   'workc_place': '경기 화성시',
#   'deadline': '~ 04/11',
#   'idx': '42296766',
#   'reg': '(1시간 전 등록)'},
#  {'title': '컨설팅 펌 - IT 컨설턴트 (~부장)',
#   'company': '에이스파트너스',
#   'career': '경력 3년↑',
#   'education': '대학교(4년)↑',
#   'employment_type': '정규직',
#   'workc_place': '서울 강남구',
#   'deadline': '채용시',
#   'idx': '42296726',
#   'reg': '(1시간 전 등록)'},
#  {'title': '데이터 플랫폼 개발자(PM)',
#   'company': '(주)에스테코',
#   'career': '경력무관',
#   'education': '대학교(4년)↑',
#   'employment_type': '정규직',
#   'workc_place': '세종 세종특별자치시',
#   'deadline': '~ 03/12',
#   'idx': '42296713',
#   'reg': '(1시간 전 등록)'},
#  {'title': '[서울/문정역] 호텔 홈페이지 개발 프로젝트 QA 모집',
#   'company': '(주)에이블유컴즈',
#   'career': '경력 2년↑',
#   'education': '대학(2,3년)↑',
#   'employment_type': '프리랜서',
#   'workc_place': '서울 서초구',
#   'deadline': '~ 03/12',
#   'idx': '42296712',
#   'reg': '(1시간 전 등록)'},
#  {'title': '[연구소] H/W 개발자 모집(경력)',
#   'company': '덕산메카시스(주)',
#   'career': '5 ~ 10년',
#   'education': '대학교(4년)↑',
#   'employment_type': '정규직',
#   'workc_place': '서울 금천구',
#   'deadline': '~ 04/11',
#   'idx': '42296687',
#   'reg': '(1시간 전 등록)'},
#  {'title': '백엔드(Python) 개발',
#   'company': '주식회사 아군',
#   'career': '경력 1년↑',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '서울 서초구',
#   'deadline': '~ 03/12',
#   'idx': '42296655',
#   'reg': '(1시간 전 등록)'},
#  {'title': 'IT개발·데이터(기술지원&SI개발&S/W外 3개 부문) 모집 공고',
#   'company': '아미스테크놀로지',
#   'career': '경력무관',
#   'education': '학력무관',
#   'employment_type': '정규직 · 계약직',
#   'workc_place': '서울 강서구',
#   'deadline': '~ 03/12',
#   'idx': '42296620',
#   'reg': '(1시간 전 등록)'},
#  {'title': '2022 웹보안 신입사원 채용 (정규직)',
#   'company': '(주)씨에스링크',
#   'career': '신입',
#   'education': '대학교(4년)↑',
#   'employment_type': '정규직',
#   'workc_place': '서울 강남구',
#   'deadline': '~ 03/18',
#   'idx': '42296609',
#   'reg': '(1시간 전 등록)'},
#  {'title': 'IT-기간계 시스템 운영/고도화 및 인프라/보안 운영',
#   'company': '에이스파트너스',
#   'career': '5 ~ 12년',
#   'education': '대학교(4년)↑',
#   'employment_type': '정규직',
#   'workc_place': '충남 천안시 동남구',
#   'deadline': '채용시',
#   'idx': '42296597',
#   'reg': '(1시간 전 등록)'},
#  {'title': '[IoT개발팀] 신입 및 경력 Mobile App. 개발자 채용',
#   'company': '(주)바인테크',
#   'career': '신입 · 경력',
#   'education': '대학교(4년)↑',
#   'employment_type': '정규직',
#   'workc_place': '서울 송파구',
#   'deadline': '~ 02/17',
#   'idx': '42296654',
#   'reg': '(1시간 전 등록)'},
#  {'title': 'IT개발·데이터(기술지원&SI개발&S/W外 3개 부문) 모집 공고',
#   'company': '아미스테크놀로지',
#   'career': '경력무관',
#   'education': '학력무관',
#   'employment_type': '정규직 · 계약직',
#   'workc_place': '서울 강서구',
#   'deadline': '~ 03/12',
#   'idx': '42296620',
#   'reg': '(1시간 전 등록)'},
#  {'title': '2022 웹보안 신입사원 채용 (정규직)',
#   'company': '(주)씨에스링크',
#   'career': '신입',
#   'education': '대학교(4년)↑',
#   'employment_type': '정규직',
#   'workc_place': '서울 강남구',
#   'deadline': '~ 03/18',
#   'idx': '42296609',
#   'reg': '(1시간 전 등록)'},
#  {'title': 'IT-기간계 시스템 운영/고도화 및 인프라/보안 운영',
#   'company': '에이스파트너스',
#   'career': '5 ~ 12년',
#   'education': '대학교(4년)↑',
#   'employment_type': '정규직',
#   'workc_place': '충남 천안시 동남구',
#   'deadline': '채용시',
#   'idx': '42296597',
#   'reg': '(1시간 전 등록)'},
#  {'title': 'Cloud Architect (~부장)',
#   'company': '에이스파트너스',
#   'career': '경력 2년↑',
#   'education': '대학교(4년)↑',
#   'employment_type': '정규직',
#   'workc_place': '서울 강남구',
#   'deadline': '채용시',
#   'idx': '42296567',
#   'reg': '(1시간 전 등록)'},
#  {'title': '[마포상암] 네트워크 엔지니어 모집 (신입)',
#   'company': '㈜ 유에이아이',
#   'career': '신입',
#   'education': '고졸↑',
#   'employment_type': '정규직',
#   'workc_place': '서울 마포구',
#   'deadline': '채용시',
#   'idx': '42296561',
#   'reg': '(1시간 전 등록)'},
#  {'title': '[인비즈소프트] IOS 앱 개발, 웹소켓 서버개발, UX/UI 기획 채용',
#   'company': '(주)인비즈소프트',
#   'career': '경력 3년↑',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '서울 강남구',
#   'deadline': '채용시',
#   'idx': '42296560',
#   'reg': '(1시간 전 등록)'},
#  {'title': 'Data Engineer (~부장)',
#   'company': '에이스파트너스',
#   'career': '경력 2년↑',
#   'education': '대학교(4년)↑',
#   'employment_type': '정규직',
#   'workc_place': '서울 강남구',
#   'deadline': '채용시',
#   'idx': '42296555',
#   'reg': '(1시간 전 등록)'},
#  {'title': '한일네트웍스 SE채용 추가모집(서울 충정로 근무)',
#   'company': '한일네트웍스(주)',
#   'career': '신입',
#   'education': '대학(2,3년)↑',
#   'employment_type': '정규직 · 계약직',
#   'workc_place': '서울 마포구',
#   'deadline': '~ 02/24',
#   'idx': '42296508',
#   'reg': '(1시간 전 등록)'},
#  {'title': '[서초/주5일] 온라인/모바일 게임테스트 인원 (신입 가능)',
#   'company': '원스탭에이치알(주)',
#   'career': '경력무관',
#   'education': '학력무관',
#   'employment_type': '계약직 · 파견직',
#   'workc_place': '서울 서초구',
#   'deadline': '~ 03/12',
#   'idx': '42296499',
#   'reg': '(1시간 전 등록)'},
#  {'title': '[뉴트리코어] ERP 시스템 개발/관리 경력직 채용(정규직)',
#   'company': '(주)에스엘바이오텍',
#   'career': '경력 4년↑',
#   'education': '대학(2,3년)↑',
#   'employment_type': '정규직',
#   'workc_place': '서울 금천구',
#   'deadline': '~ 03/12',
#   'idx': '42296500',
#   'reg': '(1시간 전 등록)'},
#  {'title': '시스템 운영 관리',
#   'company': '아주큐엠에스(주)',
#   'career': '4 ~ 7년',
#   'education': '대학(2,3년)↑',
#   'employment_type': '정규직',
#   'workc_place': '경기 용인시 수지구',
#   'deadline': '~ 03/12',
#   'idx': '42296484',
#   'reg': '(1시간 전 등록)'},
#  {'title': '(주)에스알 R&D 본부 하드웨어팀/소프트웨어팀 연구원 모집',
#   'company': '㈜에스알',
#   'career': '경력무관',
#   'education': '대학교(4년)↑',
#   'employment_type': '정규직',
#   'workc_place': '경기 의왕시',
#   'deadline': '채용시',
#   'idx': '42296479',
#   'reg': '(1시간 전 등록)'},
#  {'title': '모바일 클라이언트(Flutter, Node) 개발자 채용',
#   'company': '(주)스쿨버스',
#   'career': '신입 · 경력',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '서울전체',
#   'deadline': '~ 03/31',
#   'idx': '42296470',
#   'reg': '(1시간 전 등록)'},
#  {'title': '머신비전 애플리케이션 엔지니어 정규직 채용(신입)',
#   'company': '다빈치이미징(주)',
#   'career': '신입',
#   'education': '대학교(4년)↑',
#   'employment_type': '정규직',
#   'workc_place': '경기 안양시 동안구',
#   'deadline': '~ 03/12',
#   'idx': '42296465',
#   'reg': '(1시간 전 등록)'},
#  {'title': '[쇼핑몰] 서버 개발자',
#   'company': '(주)콰가',
#   'career': '3 ~ 6년',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '서울전체',
#   'deadline': '상시채용',
#   'idx': '42296450',
#   'reg': '(1시간 전 등록)'},
#  {'title': 'S/W개발자 (정규직 / C# MES 프로그램 개발자)',
#   'company': '(주)엔씨씨',
#   'career': '경력무관',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '대전 유성구',
#   'deadline': '~ 03/12',
#   'idx': '42296423',
#   'reg': '(1시간 전 등록)'},
#  {'title': '한일네트웍스 미래를 함께할 개발자를 찾습니다.',
#   'company': '한일네트웍스(주)',
#   'career': '경력 3년↑',
#   'education': '대학교(4년)↑',
#   'employment_type': '정규직 · 계약직',
#   'workc_place': '서울 마포구',
#   'deadline': '~ 02/24',
#   'idx': '42296399',
#   'reg': '(1시간 전 등록)'},
#  {'title': '이천] Linux, Windows, VMware 서버 운영, 스토리지 운영 경력직',
#   'company': '씨앤토트플러스(주)',
#   'career': '3 ~ 9년',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '경기 이천시',
#   'deadline': '~ 02/17',
#   'idx': '42296378',
#   'reg': '(1시간 전 등록)'},
#  {'title': '[PAY] WPF 개발자',
#   'company': '(주)콰가',
#   'career': '2 ~ 6년',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '서울전체',
#   'deadline': '상시채용',
#   'idx': '42296324',
#   'reg': '(1시간 전 등록)'},
#  {'title': '인사총무/IT관리/해외영업/내수영업/수출입 신입 및 경력 채용',
#   'company': '(주)신티에스',
#   'career': '신입 · 경력',
#   'education': '학력무관',
#   'employment_type': '정규직 · 인턴직',
#   'workc_place': '서울 구로구',
#   'deadline': '~ 02/24',
#   'idx': '42296285',
#   'reg': '(1시간 전 등록)'},
#  {'title': '2022 (주) 에스유 온라인마케팅, 웹디자인 및 코딩 가능자 모집',
#   'company': '(주)에스유',
#   'career': '경력무관',
#   'education': '학력무관',
#   'employment_type': '정규직 · 계약직',
#   'workc_place': '충북 청주시 흥덕구',
#   'deadline': '~ 03/12',
#   'idx': '42296247',
#   'reg': '(1시간 전 등록)'},
#  {'title': '[교원그룹] IT기반기술팀 신입직 수시채용(IT지원/IT자산관리)',
#   'company': '(주)교원프라퍼티',
#   'career': '신입',
#   'education': '대학(2,3년)↑',
#   'employment_type': '정규직',
#   'workc_place': '서울 중구',
#   'deadline': '~ 02/20',
#   'idx': '42296236',
#   'reg': '(1시간 전 등록)'},
#  {'title': '2022년 상반기 IT컨설팅, 유지보수 경력 채용합니다',
#   'company': '(주)우리아이티',
#   'career': '경력 2년↑',
#   'education': '대학(2,3년)↑',
#   'employment_type': '정규직',
#   'workc_place': '부산 동구',
#   'deadline': '~ 04/11',
#   'idx': '42296232',
#   'reg': '(1시간 전 등록)'},
#  {'title': 'Web Frontend (Vue.js) 개발자 채용',
#   'company': '(주)지오하임',
#   'career': '경력 2년↑',
#   'education': '학력무관',
#   'employment_type': '정규직 · 계약직',
#   'workc_place': '서울 서초구',
#   'deadline': '~ 03/12',
#   'idx': '42296225',
#   'reg': '(1시간 전 등록)'},
#  {'title': 'Algorithm&Control SW개발 경력직 채용',
#   'company': '오씨아이파워(주)',
#   'career': '신입 · 경력',
#   'education': '석사↑',
#   'employment_type': '정규직',
#   'workc_place': '서울 중구',
#   'deadline': '~ 03/06',
#   'idx': '42296220',
#   'reg': '(1시간 전 등록)'},
#  {'title': 'User Interface SW개발자 채용',
#   'company': '오씨아이파워(주)',
#   'career': '신입 · 경력',
#   'education': '대학교(4년)↑',
#   'employment_type': '정규직',
#   'workc_place': '서울 중구',
#   'deadline': '~ 03/06',
#   'idx': '42296200',
#   'reg': '(1시간 전 등록)'},
#  {'title': '연구소 소프트웨어 개발(MES, SECS/GEM 분야) 엔지니어 채용',
#   'company': '헬러코리아(주)',
#   'career': '경력 5년↑',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '경기 수원시 권선구',
#   'deadline': '~ 04/11',
#   'idx': '42296193',
#   'reg': '(1시간 전 등록)'},
#  {'title': 'UI/UX디자이너, 퍼블리셔 경력직 채용',
#   'company': '(주)다엔',
#   'career': '경력무관',
#   'education': '대학(2,3년)↑',
#   'employment_type': '정규직 · 계약직',
#   'workc_place': '서울 강서구',
#   'deadline': '~ 03/12',
#   'idx': '42296190',
#   'reg': '(1시간 전 등록)'},
#  {'title': '[PTKOREA] 디지털 미디어 데이터 분석가(Data Analyst/계약)',
#   'company': '펑타이그레이터차이나(유)',
#   'career': '2 ~ 6년',
#   'education': '대학교(4년)↑',
#   'employment_type': '계약직',
#   'workc_place': '서울 강남구',
#   'deadline': '~ 03/06',
#   'idx': '42296124',
#   'reg': '(1시간 전 등록)'},
#  {'title': 'Android Application 개발자 채용',
#   'company': '(주)지오하임',
#   'career': '경력 3년↑',
#   'education': '학력무관',
#   'employment_type': '정규직 · 계약직',
#   'workc_place': '서울 서초구',
#   'deadline': '~ 03/12',
#   'idx': '42296093',
#   'reg': '(2시간 전 등록)'},
#  {'title': 'iOS Application 개발자 채용',
#   'company': '(주)지오하임',
#   'career': '경력 3년↑',
#   'education': '학력무관',
#   'employment_type': '정규직 · 계약직',
#   'workc_place': '서울 서초구',
#   'deadline': '~ 03/12',
#   'idx': '42296034',
#   'reg': '(2시간 전 등록)'},
#  {'title': '기간제 근로자 채용 공고',
#   'company': '대한상공회의소 충남인력개발원',
#   'career': '경력무관',
#   'education': '학력무관',
#   'employment_type': '계약직',
#   'workc_place': '충남 공주시',
#   'deadline': '~ 02/21',
#   'idx': '42295980',
#   'reg': '(2시간 전 등록)'},
#  {'title': 'OA 유지보수 인력 경력/신입 채용 공고 - 정규직',
#   'company': '주식회사엠에스이',
#   'career': '3 ~ 10년',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '서울 송파구',
#   'deadline': '채용시',
#   'idx': '42295963',
#   'reg': '(2시간 전 등록)'},
#  {'title': 'Veritas Netbackup 엔지니어 경력채용 (대구지사)',
#   'company': '(주)지티솔루션',
#   'career': '3 ~ 10년',
#   'education': '대학(2,3년)↑',
#   'employment_type': '정규직',
#   'workc_place': '대구 동구',
#   'deadline': '~ 03/12',
#   'idx': '42295942',
#   'reg': '(2시간 전 등록)'},
#  {'title': '2022년 보안 S/W기술지원 엔지니어 신입/경력 채용 (정규직)',
#   'company': '(주)인정보',
#   'career': '경력무관',
#   'education': '대학(2,3년)↑',
#   'employment_type': '정규직',
#   'workc_place': '서울 금천구',
#   'deadline': '~ 03/11',
#   'idx': '42295941',
#   'reg': '(2시간 전 등록)'},
#  {'title': '[긴급]자동차관련대기업 재무회계 대리급',
#   'company': '닥터파인드',
#   'career': '4 ~ 9년',
#   'education': '대학교(4년)↑',
#   'employment_type': '정규직',
#   'workc_place': '서울 송파구',
#   'deadline': '~ 02/18',
#   'idx': '42295922',
#   'reg': '(2시간 전 등록)'},
#  {'title': '[글로벌디지털마케팅] 모션 그래픽',
#   'company': '콘센트릭스서비스코리아(유)',
#   'career': '경력 5년↑',
#   'education': '대학(2,3년)↑',
#   'employment_type': '정규직',
#   'workc_place': '서울 용산구',
#   'deadline': '~ 03/12',
#   'idx': '42295905',
#   'reg': '(2시간 전 등록)'},
#  {'title': '(주)피앤씨랩스, 기술지원팀 팀원 채용',
#   'company': '(주)피앤씨랩스',
#   'career': '경력무관',
#   'education': '고졸↑',
#   'employment_type': '정규직',
#   'workc_place': '경기 오산시',
#   'deadline': '~ 03/12',
#   'idx': '42295894',
#   'reg': '(2시간 전 등록)'},
#  {'title': '스마트폰 필드 테스트 정규직 사원 모집(수원팀)',
#   'company': '(주)에스이에스모바일',
#   'career': '경력무관',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '경기 수원시 영통구',
#   'deadline': '~ 02/16',
#   'idx': '42295880',
#   'reg': '(2시간 전 등록)'},
#  {'title': '[외국계기업] Retail Store Support Engineer',
#   'company': '(주)엠아이티마스',
#   'career': '신입 · 경력',
#   'education': '대학(2,3년)↑',
#   'employment_type': '정규직',
#   'workc_place': '서울 용산구',
#   'deadline': '~ 03/12',
#   'idx': '42295862',
#   'reg': '(2시간 전 등록)'},
#  {'title': '스마트폰 통화 품질 테스트 정규직 사원 모집(수원지역)',
#   'company': '(주)에스이에스모바일',
#   'career': '경력무관',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '경기 수원시 영통구',
#   'deadline': '~ 02/16',
#   'idx': '42295856',
#   'reg': '(2시간 전 등록)'},
#  {'title': '(주)참케어 펌웨어 기반 제품 개발 연구원 모집',
#   'company': '참케어',
#   'career': '경력 3년↑',
#   'education': '대학(2,3년)↑',
#   'employment_type': '정규직',
#   'workc_place': '서울 금천구',
#   'deadline': '~ 03/12',
#   'idx': '42295841',
#   'reg': '(2시간 전 등록)'},
#  {'title': '스마트폰 필드 테스트 정규직 사원 모집(구미팀)',
#   'company': '(주)에스이에스모바일',
#   'career': '경력무관',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '경북 구미시',
#   'deadline': '~ 02/16',
#   'idx': '42295837',
#   'reg': '(2시간 전 등록)'},
#  {'title': '인공지능 / 머신러닝 개발자 채용',
#   'company': '(주)지오하임',
#   'career': '경력무관',
#   'education': '석사↑',
#   'employment_type': '정규직 · 계약직',
#   'workc_place': '서울 서초구',
#   'deadline': '~ 03/12',
#   'idx': '42295832',
#   'reg': '(2시간 전 등록)'},
#  {'title': '미들웨어(WEB/WAS)운영관리',
#   'company': '(주)씨앤아이테크',
#   'career': '경력 6년↑',
#   'education': '학력무관',
#   'employment_type': '정규직 · 프리랜서',
#   'workc_place': '경기 성남시 분당구',
#   'deadline': '~ 03/12',
#   'idx': '42295824',
#   'reg': '(2시간 전 등록)'},
#  {'title': '운영/개발 - 초/중/고급 - .NET / C# 개발',
#   'company': '(주)텐노드솔루션',
#   'career': '1 ~ 20년',
#   'education': '대학(2,3년)↑',
#   'employment_type': '정규직 · 프리랜서',
#   'workc_place': '경기 성남시 분당구',
#   'deadline': '~ 03/12',
#   'idx': '42295820',
#   'reg': '(2시간 전 등록)'},
#  {'title': '연구소 제어설계팀 경력무관 채용(정규직)',
#   'company': '(주)터보맥스',
#   'career': '경력무관',
#   'education': '대학(2,3년)↑',
#   'employment_type': '정규직',
#   'workc_place': '충북 청주시 흥덕구',
#   'deadline': '~ 02/25',
#   'idx': '42295817',
#   'reg': '(2시간 전 등록)'},
#  {'title': '스마트폰 통화 품질 테스트 정규직 사원 모집(구미지역)',
#   'company': '(주)에스이에스모바일',
#   'career': '경력무관',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '경북 구미시',
#   'deadline': '~ 02/16',
#   'idx': '42295809',
#   'reg': '(2시간 전 등록)'},
#  {'title': '이루인포 IT 솔루션 및 서버 스토리지 영업 경력 사원 채용',
#   'company': '(주)이루인포',
#   'career': '경력무관',
#   'education': '대학(2,3년)↑',
#   'employment_type': '정규직',
#   'workc_place': '서울 강남구',
#   'deadline': '~ 03/12',
#   'idx': '42295790',
#   'reg': '(2시간 전 등록)'},
#  {'title': '각 부문 신입/경력 사원 모집',
#   'company': '(주)글로벌밴',
#   'career': '신입 · 경력',
#   'education': '고졸↑',
#   'employment_type': '정규직',
#   'workc_place': '서울 마포구',
#   'deadline': '~ 02/22',
#   'idx': '42295780',
#   'reg': '(2시간 전 등록)'},
#  {'title': '백업솔루션 운영관리(HPDP)',
#   'company': '(주)씨앤아이테크',
#   'career': '경력 6년↑',
#   'education': '학력무관',
#   'employment_type': '정규직 · 프리랜서',
#   'workc_place': '경기 성남시 분당구',
#   'deadline': '~ 03/12',
#   'idx': '42295735',
#   'reg': '(2시간 전 등록)'},
#  {'title': '[역삼/복지상위] 글로벌 1위 화학&반도체기업 CSR 경력직 채용',
#   'company': '(주)맨파워그룹코리아',
#   'career': '경력 1년↑',
#   'education': '대학교(4년)↑',
#   'employment_type': '계약직 · 파견직',
#   'workc_place': '서울 강남구',
#   'deadline': '~ 02/15',
#   'idx': '42295734',
#   'reg': '(2시간 전 등록)'},
#  {'title': '프론트엔드 개발자',
#   'company': '(주)피플리',
#   'career': '3 ~ 7년',
#   'education': '대학(2,3년)↑',
#   'employment_type': '정규직',
#   'workc_place': '서울전체',
#   'deadline': '상시채용',
#   'idx': '42295711',
#   'reg': '(2시간 전 등록)'},
#  {'title': '2월 부문별 경력사원 수시채용 공고',
#   'company': '우미건설(주)',
#   'career': '경력',
#   'education': '대학(2,3년)↑',
#   'employment_type': '정규직 · 계약직',
#   'workc_place': '서울 강남구',
#   'deadline': '~ 02/20',
#   'idx': '42295676',
#   'reg': '(2시간 전 등록)'},
#  {'title': '신한금융투자 업무 개발 및 운영 (SM) - PRO-C',
#   'company': '(주)나래에스앤씨',
#   'career': '경력 3년↑',
#   'education': '학력무관',
#   'employment_type': '정규직 · 계약직',
#   'workc_place': '서울 영등포구',
#   'deadline': '~ 02/14',
#   'idx': '42295677',
#   'reg': '(2시간 전 등록)'},
#  {'title': '백엔드 개발자',
#   'company': '(주)피플리',
#   'career': '7 ~ 15년',
#   'education': '대학(2,3년)↑',
#   'employment_type': '정규직',
#   'workc_place': '서울전체',
#   'deadline': '상시채용',
#   'idx': '42295652',
#   'reg': '(2시간 전 등록)'},
#  {'title': '[경력] 개발 인프라 구축 및 운영 담당자',
#   'company': '(주)안랩',
#   'career': '경력무관',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '경기 성남시 분당구',
#   'deadline': '~ 02/24',
#   'idx': '42295649',
#   'reg': '(2시간 전 등록)'},
#  {'title': '[신입]서버 및 네트워크 엔지니어 공고(정규직)',
#   'company': '(주)와이젠정보기술',
#   'career': '신입',
#   'education': '대학교(4년)↑',
#   'employment_type': '정규직',
#   'workc_place': '서울 중구',
#   'deadline': '~ 03/10',
#   'idx': '42295644',
#   'reg': '(2시간 전 등록)'},
#  {'title': '포항에서 근무할 React.js 개발자를 모집합니다.',
#   'company': '(주)제이엘유',
#   'career': '경력 2년↑',
#   'education': '대학교(4년)↑',
#   'employment_type': '정규직 · 계약직',
#   'workc_place': '경기 수원시 영통구',
#   'deadline': '~ 03/12',
#   'idx': '42295637',
#   'reg': '(2시간 전 등록)'},
#  {'title': '글로벌 게임 자회사 소개팅앱 서버 개발',
#   'company': 'KY컨설팅그룹',
#   'career': '3 ~ 10년',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '서울 서초구',
#   'deadline': '채용시',
#   'idx': '42295633',
#   'reg': '(2시간 전 등록)'},
#  {'title': '안드로이드 개발자',
#   'company': '(주)피플리',
#   'career': '3 ~ 7년',
#   'education': '대학(2,3년)↑',
#   'employment_type': '정규직',
#   'workc_place': '서울전체',
#   'deadline': '상시채용',
#   'idx': '42295625',
#   'reg': '(2시간 전 등록)'},
#  {'title': '[정규직] 클라우드 엔지니어 모집',
#   'company': '오케스트로(주)',
#   'career': '경력무관',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '서울 영등포구',
#   'deadline': '~ 03/12',
#   'idx': '42295615',
#   'reg': '(2시간 전 등록)'},
#  {'title': '솔루션사업부 IT개발·데이터 경력/신입 모집',
#   'company': '(주)인바이트',
#   'career': '신입 · 경력',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '경기 부천시',
#   'deadline': '~ 04/11',
#   'idx': '42295603',
#   'reg': '(2시간 전 등록)'},
#  {'title': '글로벌 게임 자회사 소개팅앱 모바일 클라이언트 개발',
#   'company': 'KY컨설팅그룹',
#   'career': '3 ~ 10년',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '서울 서초구',
#   'deadline': '채용시',
#   'idx': '42295599',
#   'reg': '(2시간 전 등록)'},
#  {'title': '신한저축은행 품질관리(QA) 및 React(AA) 업무 - SI',
#   'company': '(주)나래에스앤씨',
#   'career': '경력 6년↑',
#   'education': '학력무관',
#   'employment_type': '정규직 · 계약직',
#   'workc_place': '서울 영등포구',
#   'deadline': '~ 02/14',
#   'idx': '42295578',
#   'reg': '(2시간 전 등록)'},
#  {'title': '전문연구요원 엔지니어 채용(병역특례)',
#   'company': '(주)링크솔루션',
#   'career': '경력무관',
#   'education': '석사↑',
#   'employment_type': '정규직',
#   'workc_place': '경기 시흥시',
#   'deadline': '~ 03/12',
#   'idx': '42295533',
#   'reg': '(2시간 전 등록)'},
#  {'title': '신한금융투자 개발 및 운영 (SM)',
#   'company': '(주)나래에스앤씨',
#   'career': '경력 5년↑',
#   'education': '학력무관',
#   'employment_type': '정규직 · 계약직',
#   'workc_place': '서울 영등포구',
#   'deadline': '~ 02/14',
#   'idx': '42295496',
#   'reg': '(2시간 전 등록)'},
#  {'title': '현대IT&E 2022년 경력사원 수시채용',
#   'company': '(주)현대아이티앤이',
#   'career': '경력 3년↑',
#   'education': '대학교(4년)↑',
#   'employment_type': '정규직',
#   'workc_place': '서울 강남구',
#   'deadline': '채용시',
#   'idx': '42295473',
#   'reg': '(2시간 전 등록)'},
#  {'title': 'IT 기획 및 인프라 관리(ERP MES 등) 경력직 채용',
#   'company': '(주)탑인터큐브',
#   'career': '경력 3년↑',
#   'education': '대학(2,3년)↑',
#   'employment_type': '정규직',
#   'workc_place': '경기 성남시 분당구',
#   'deadline': '~ 03/12',
#   'idx': '42295461',
#   'reg': '(2시간 전 등록)'},
#  {'title': '[기술지원]부산에서 CAD/CAM 신규/경력직 엔지니어를 모집합니다',
#   'company': '(주)하나티에스',
#   'career': '신입 · 경력',
#   'education': '대학(2,3년)↑',
#   'employment_type': '정규직',
#   'workc_place': '부산 북구',
#   'deadline': '~ 03/12',
#   'idx': '42295450',
#   'reg': '(2시간 전 등록)'},
#  {'title': '[알파프로] 주식 메인 전문가/애널리스트 모십니다.',
#   'company': 'I.S.I.C',
#   'career': '경력무관',
#   'education': '고졸↑',
#   'employment_type': '정규직',
#   'workc_place': '서울 강남구',
#   'deadline': '~ 03/12',
#   'idx': '42295445',
#   'reg': '(2시간 전 등록)'},
#  {'title': '[모빌테크] SLAM 개발자 채용 공고',
#   'company': '주식회사 모빌테크',
#   'career': '신입 · 경력',
#   'education': '대학교(4년)↑',
#   'employment_type': '정규직',
#   'workc_place': '서울 서초구',
#   'deadline': '상시채용',
#   'idx': '42295441',
#   'reg': '(2시간 전 등록)'},
#  {'title': '[웹개발] 주식회사 더블티 개발자 경력직 채용',
#   'company': '(주)더블티',
#   'career': '경력무관',
#   'education': '대학교(4년)↑',
#   'employment_type': '정규직',
#   'workc_place': '경기 수원시 영통구',
#   'deadline': '~ 03/12',
#   'idx': '42295399',
#   'reg': '(2시간 전 등록)'},
#  {'title': '총무팀 IT부문 신입사원 채용',
#   'company': '연성정밀화학(주)',
#   'career': '신입',
#   'education': '대학교(4년)↑',
#   'employment_type': '정규직',
#   'workc_place': '경기 화성시',
#   'deadline': '~ 02/23',
#   'idx': '42295396',
#   'reg': '(2시간 전 등록)'},
#  {'title': '[정규직]대한항공 및 한진그룹 전산장비 유지보수',
#   'company': '(주)케이원',
#   'career': '경력무관',
#   'education': '고졸↑',
#   'employment_type': '정규직',
#   'workc_place': '서울 강서구',
#   'deadline': '~ 03/12',
#   'idx': '42295378',
#   'reg': '(2시간 전 등록)'},
#  {'title': '[ktcs] kt플라자 군위점  22년 상반기 공개채용',
#   'company': '(주)케이티씨에스',
#   'career': '신입 · 경력',
#   'education': '고졸↑',
#   'employment_type': '계약직',
#   'workc_place': '경북 상주시',
#   'deadline': '채용시',
#   'idx': '42295341',
#   'reg': '(2시간 전 등록)'},
#  {'title': '정보통신 기술 전문가 모집 (네트워크 CCTV NVR VMS)',
#   'company': '(주)브이엠소프트',
#   'career': '경력무관',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '서울 금천구',
#   'deadline': '~ 02/25',
#   'idx': '42295332',
#   'reg': '(2시간 전 등록)'},
#  {'title': '[창원] CCTV 설치 및  네트워크 현장직 근무자 모집합니다',
#   'company': '광정보시스템 주식회사',
#   'career': '경력무관',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '경남 창원시',
#   'deadline': '~ 03/12',
#   'idx': '42295288',
#   'reg': '(2시간 전 등록)'},
#  {'title': '경영지원팀 경력자 구인',
#   'company': '(주)미르시스템',
#   'career': '5 ~ 15년',
#   'education': '대학(2,3년)↑',
#   'employment_type': '정규직',
#   'workc_place': '경기 수원시 영통구',
#   'deadline': '~ 03/12',
#   'idx': '42295284',
#   'reg': '(2시간 전 등록)'},
#  {'title': '[정규직] 정보보호 영업, 프로젝트 관리, 프로젝트발굴',
#   'company': '한국정보보안원',
#   'career': '경력무관',
#   'education': '대학(2,3년)↑',
#   'employment_type': '정규직',
#   'workc_place': '서울 구로구',
#   'deadline': '~ 03/12',
#   'idx': '42295278',
#   'reg': '(2시간 전 등록)'},
#  {'title': '[하드웨어 엔지니어] H/W개발팀 경력  채용공고',
#   'company': '(주)미래시스템',
#   'career': '2 ~ 10년',
#   'education': '대학교(4년)↑',
#   'employment_type': '정규직',
#   'workc_place': '대전 유성구',
#   'deadline': '~ 03/12',
#   'idx': '42295276',
#   'reg': '(2시간 전 등록)'},
#  {'title': '더블유엠어시 대전지점에서 풀스텍 개발자 개발자를 모집합니다',
#   'company': '더블유엠어시',
#   'career': '경력 2년↑',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '대전 유성구',
#   'deadline': '~ 02/16',
#   'idx': '42295242',
#   'reg': '(2시간 전 등록)'},
#  {'title': '머신비젼 검사 알고리즘 개발 / 운영 채용',
#   'company': '(주)영우디에스피',
#   'career': '경력무관',
#   'education': '대학교(4년)↑',
#   'employment_type': '정규직',
#   'workc_place': '경기 성남시 분당구',
#   'deadline': '~ 04/11',
#   'idx': '42295241',
#   'reg': '(2시간 전 등록)'},
#  {'title': '[정규직] 정보보호 프로젝트 관리',
#   'company': '한국정보보안원',
#   'career': '경력무관',
#   'education': '대학(2,3년)↑',
#   'employment_type': '정규직',
#   'workc_place': '서울 구로구',
#   'deadline': '~ 03/12',
#   'idx': '42295235',
#   'reg': '(2시간 전 등록)'},
#  {'title': '텍스트 분석 및 NLP/NLU 알고리즘 개발자 모집 [신입/경력]',
#   'company': '(주)인사이저',
#   'career': '신입 · 경력',
#   'education': '대학교(4년)↑',
#   'employment_type': '정규직',
#   'workc_place': '서울 성동구',
#   'deadline': '~ 03/12',
#   'idx': '42295218',
#   'reg': '(2시간 전 등록)'},
#  {'title': '[부산] CCTV 설치 및  네트워크 현장직 근무자 모집합니다',
#   'company': '광정보시스템 주식회사',
#   'career': '경력무관',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '부산 동구',
#   'deadline': '~ 03/12',
#   'idx': '42295213',
#   'reg': '(2시간 전 등록)'},
#  {'title': '[정규직] 취약점 진단',
#   'company': '한국정보보안원',
#   'career': '경력무관',
#   'education': '대학(2,3년)↑',
#   'employment_type': '정규직',
#   'workc_place': '서울 구로구',
#   'deadline': '~ 03/12',
#   'idx': '42295205',
#   'reg': '(2시간 전 등록)'},
#  {'title': '[울산] CCTV 설치 및  네트워크 현장직 근무자 모집합니다',
#   'company': '광정보시스템 주식회사',
#   'career': '경력무관',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '울산 남구',
#   'deadline': '~ 03/12',
#   'idx': '42295184',
#   'reg': '(2시간 전 등록)'},
#  {'title': '더블유엠어시에서 풀스텍 개발자를 모집합니다.',
#   'company': '더블유엠어시',
#   'career': '경력 2년↑',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '전북 전주시 완산구',
#   'deadline': '~ 02/16',
#   'idx': '42295173',
#   'reg': '(2시간 전 등록)'},
#  {'title': '[비엔에스테크] 기술본부 신입/경력직 채용',
#   'company': '(주)비엔에스테크',
#   'career': '신입 · 경력',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '경기 성남시 중원구',
#   'deadline': '~ 02/17',
#   'idx': '42295169',
#   'reg': '(2시간 전 등록)'},
#  {'title': 'POS시스템 및 카드단말기 설치, 유지보수 정규직 채용',
#   'company': '나인정보통신주식회사',
#   'career': '1 ~ 3년',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '서울 금천구',
#   'deadline': '~ 03/12',
#   'idx': '42295132',
#   'reg': '(2시간 전 등록)'},
#  {'title': '[초긴급] 안드로이드 어플리케이션 개발자 모집',
#   'company': '(주)제이엘유',
#   'career': '경력 9년↑',
#   'education': '대학(2,3년)↑',
#   'employment_type': '프리랜서',
#   'workc_place': '경기 수원시 영통구',
#   'deadline': '~ 03/12',
#   'idx': '42295124',
#   'reg': '(2시간 전 등록)'},
#  {'title': '[여수/에이텍씨앤] LG그룹사 내 상주 PC/OA 유지보수',
#   'company': '(주)에이텍씨앤',
#   'career': '경력무관',
#   'education': '학력무관',
#   'employment_type': '계약직',
#   'workc_place': '전남 여수시',
#   'deadline': '~ 03/12',
#   'idx': '42295116',
#   'reg': '(2시간 전 등록)'},
#  {'title': '[국내 AI 어플리케이션 기업] .Net/ASP.NET개발자 (시니어급)',
#   'company': '(주)리앤파트너',
#   'career': '10 ~ 14년',
#   'education': '대학(2,3년)↑',
#   'employment_type': '정규직',
#   'workc_place': '서울 서초구',
#   'deadline': '~ 03/12',
#   'idx': '42295094',
#   'reg': '(3시간 전 등록)'},
#  {'title': '[대기업 계열사] 서버 개발자 (정규직)',
#   'company': '(주)리앤파트너',
#   'career': '경력 4년↑',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '서울 서초구',
#   'deadline': '~ 03/12',
#   'idx': '42295088',
#   'reg': '(3시간 전 등록)'},
#  {'title': '[국내최대 가상자산거래소기업] 백엔드 (정규직)',
#   'company': '(주)리앤파트너',
#   'career': '경력 5년↑',
#   'education': '대학교(4년)↑',
#   'employment_type': '정규직',
#   'workc_place': '서울 서초구',
#   'deadline': '~ 03/12',
#   'idx': '42295082',
#   'reg': '(3시간 전 등록)'},
#  {'title': '하이브리드 앱 보안 솔루션 개발 [보충역, 전직, 전문연구요원]',
#   'company': '(주)스틸리언',
#   'career': '경력무관',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '서울 용산구',
#   'deadline': '채용시',
#   'idx': '42295055',
#   'reg': '(3시간 전 등록)'},
#  {'title': '[부천] SDN NFV 솔루션 전문 기업 /경력직 채용',
#   'company': 'YL Career',
#   'career': '경력 1년↑',
#   'education': '대학(2,3년)↑',
#   'employment_type': '정규직',
#   'workc_place': '경기 부천시',
#   'deadline': '채용시',
#   'idx': '42295047',
#   'reg': '(3시간 전 등록)'},
#  {'title': '[주식회사 꿀비]상반기 경력직 채용공고(웹개발)',
#   'company': '(주)꿀비',
#   'career': '경력 3년↑',
#   'education': '대학교(4년)↑',
#   'employment_type': '정규직',
#   'workc_place': '대전 서구',
#   'deadline': '~ 02/25',
#   'idx': '42295042',
#   'reg': '(3시간 전 등록)'},
#  {'title': '공공기관 차세대 데이터정비대상 추출(DQ) 고급 개발자 모집',
#   'company': '한국비앤에스시스템(주)',
#   'career': '경력 9년↑',
#   'education': '대학(2,3년)↑',
#   'employment_type': '프리랜서',
#   'workc_place': '서울 서초구',
#   'deadline': '~ 02/16',
#   'idx': '42295031',
#   'reg': '(3시간 전 등록)'},
#  {'title': '정보 보안 경력자 채용 (5년 - 10년차)',
#   'company': '(주)투비파트너즈',
#   'career': '5 ~ 10년',
#   'education': '대학교(4년)↑',
#   'employment_type': '정규직',
#   'workc_place': '서울 서초구',
#   'deadline': '~ 02/17',
#   'idx': '42295027',
#   'reg': '(3시간 전 등록)'},
#  {'title': '[주식회사 꿀비]상반기 경력직 채용공고(임베디드 개발)',
#   'company': '(주)꿀비',
#   'career': '경력 2년↑',
#   'education': '대학교(4년)↑',
#   'employment_type': '정규직',
#   'workc_place': '대전 서구',
#   'deadline': '~ 02/25',
#   'idx': '42295023',
#   'reg': '(3시간 전 등록)'},
#  {'title': '정보통신 전문 회사 사원 모집',
#   'company': '(주) 에스엠에이시스템',
#   'career': '경력무관',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '울산 남구',
#   'deadline': '~ 03/12',
#   'idx': '42294999',
#   'reg': '(3시간 전 등록)'},
#  {'title': '공공기관 차세대 고급 개발자 모집 (분석/설계/JAVA)',
#   'company': '한국비앤에스시스템(주)',
#   'career': '경력 9년↑',
#   'education': '대학(2,3년)↑',
#   'employment_type': '프리랜서',
#   'workc_place': '서울 서초구',
#   'deadline': '~ 02/16',
#   'idx': '42294998',
#   'reg': '(3시간 전 등록)'},
#  {'title': '국방 및 무인화 응용소프트웨어(C#,C++) 개발자 채용모집',
#   'company': '주식회사 에프엠(FM Inc.)',
#   'career': '신입 · 경력',
#   'education': '대학교(4년)↑',
#   'employment_type': '정규직',
#   'workc_place': '대전 유성구',
#   'deadline': '~ 04/11',
#   'idx': '42294961',
#   'reg': '(3시간 전 등록)'},
#  {'title': '백엔드 개발자 (쥬니어/시니어)',
#   'company': '(주)스퀘어스',
#   'career': '2 ~ 15년',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '서울전체',
#   'deadline': '~ 02/27',
#   'idx': '42294939',
#   'reg': '(3시간 전 등록)'},
#  {'title': '2022년 부문별 신입/경력 채용',
#   'company': '(주)브이씨텍',
#   'career': '신입 · 경력',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '서울 금천구',
#   'deadline': '~ 02/18',
#   'idx': '42294936',
#   'reg': '(3시간 전 등록)'},
#  {'title': '웹개발자(프로그래머) 모집',
#   'company': '(주)스마트엠',
#   'career': '경력 2년↑',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '경기 성남시 중원구',
#   'deadline': '~ 03/12',
#   'idx': '42294897',
#   'reg': '(3시간 전 등록)'},
#  {'title': '[미국] Java/DB개발 2개 부문 (H자동차 텔레매틱스)',
#   'company': '(주)솔로몬텍',
#   'career': '경력 5년↑',
#   'education': '학력무관',
#   'employment_type': '정규직 · 계약직',
#   'workc_place': '미국 로스앤젤레스',
#   'deadline': '~ 04/11',
#   'idx': '42294877',
#   'reg': '(3시간 전 등록)'},
#  {'title': '22년 삼성MPS 정규직 신입/경력 채용 - 서비스관리직, 기술직',
#   'company': '(주)삼성엠피에스',
#   'career': '신입 · 경력',
#   'education': '대학(2,3년)↑',
#   'employment_type': '정규직',
#   'workc_place': '서울 서초구',
#   'deadline': '~ 02/28',
#   'idx': '42294849',
#   'reg': '(3시간 전 등록)'},
#  {'title': '웹(WEB) 개발자 채용(병역특례 가능)',
#   'company': '(주)이엔피게임즈',
#   'career': '경력무관',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '서울 금천구',
#   'deadline': '~ 02/28',
#   'idx': '42294824',
#   'reg': '(3시간 전 등록)'},
#  {'title': '(주)스마트큐브 정규직 채용(디자이너,S/W,H/W,펌웨어 개발자)',
#   'company': '(주)스마트큐브',
#   'career': '경력 3년↑',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '서울 마포구',
#   'deadline': '~ 03/12',
#   'idx': '42294816',
#   'reg': '(3시간 전 등록)'},
#  {'title': 'java분야, c#분야 개발자 모집',
#   'company': '스마티소프트(주)',
#   'career': '2 ~ 20년',
#   'education': '대학(2,3년)↑',
#   'employment_type': '정규직',
#   'workc_place': '경기 성남시 수정구',
#   'deadline': '~ 02/28',
#   'idx': '42294804',
#   'reg': '(3시간 전 등록)'},
#  {'title': '[강서구 마곡] 쇼핑몰 고도화 및 운영 퍼블리셔(스크립터) 모집',
#   'company': '(주)소셜앱스',
#   'career': '경력 4년↑',
#   'education': '학력무관',
#   'employment_type': '정규직 · 계약직',
#   'workc_place': '서울 강서구',
#   'deadline': '~ 03/12',
#   'idx': '42294794',
#   'reg': '(3시간 전 등록)'},
#  {'title': '유지보수(AS) 상주 경력사원 모집',
#   'company': '(주)엘제이텍',
#   'career': '경력 1년↑',
#   'education': '고졸↑',
#   'employment_type': '정규직',
#   'workc_place': '서울 중구',
#   'deadline': '~ 03/12',
#   'idx': '42294772',
#   'reg': '(3시간 전 등록)'},
#  {'title': '[정규직] 전산팀 신입, 경력사원 채용',
#   'company': '대원전선㈜',
#   'career': '신입 · 경력',
#   'education': '대학(2,3년)↑',
#   'employment_type': '정규직',
#   'workc_place': '충남 예산군',
#   'deadline': '~ 03/12',
#   'idx': '42294738',
#   'reg': '(3시간 전 등록)'},
#  {'title': '마이데이터 사업기획/대리과장/강남구/블록체인스타트업',
#   'company': '오픈포지션',
#   'career': '4 ~ 13년',
#   'education': '대학교(4년)↑',
#   'employment_type': '정규직',
#   'workc_place': '서울 강남구',
#   'deadline': '~ 02/15',
#   'idx': '42294730',
#   'reg': '(3시간 전 등록)'},
#  {'title': '[연봉8000이상]임신준비플랫폼1위 Java, Spring 서버개발자 모집',
#   'company': '(주)스마일랩',
#   'career': '경력 5년↑',
#   'education': '대학교(4년)↑',
#   'employment_type': '정규직',
#   'workc_place': '서울 송파구',
#   'deadline': '~ 04/11',
#   'idx': '42294711',
#   'reg': '(3시간 전 등록)'},
#  {'title': '[원더피플]데이터랩팀 데이터엔지니어(DBA) 모집',
#   'company': '(주)원더피플',
#   'career': '경력 3년↑',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '서울 강남구',
#   'deadline': '~ 04/11',
#   'idx': '42294668',
#   'reg': '(3시간 전 등록)'},
#  {'title': '[외국계-계약직] Accountant & Admin',
#   'company': '에이치알넷원(주)',
#   'career': '경력 3년↑',
#   'education': '학력무관',
#   'employment_type': '계약직',
#   'workc_place': '서울 강남구',
#   'deadline': '~ 02/25',
#   'idx': '42294664',
#   'reg': '(3시간 전 등록)'},
#  {'title': '[원더피플]데이터랩팀 데이터엔지니어 모집',
#   'company': '(주)원더피플',
#   'career': '경력 3년↑',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '서울 강남구',
#   'deadline': '~ 04/11',
#   'idx': '42294634',
#   'reg': '(3시간 전 등록)'},
#  {'title': '2022년 공개채용[연구/기획/영업/개발/디자인]',
#   'company': '(주)옴니씨앤에스',
#   'career': '신입 · 경력',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '서울 구로구',
#   'deadline': '~ 03/12',
#   'idx': '42294625',
#   'reg': '(3시간 전 등록)'},
#  {'title': 'VR/AR 유니티, 언리얼 개발자 채용(정규직/계약직)',
#   'company': '오모션 주식회사',
#   'career': '경력무관',
#   'education': '대학교(4년)↑',
#   'employment_type': '정규직 · 계약직',
#   'workc_place': '서울 마포구',
#   'deadline': '~ 03/12',
#   'idx': '42294602',
#   'reg': '(3시간 전 등록)'},
#  {'title': '시스템 개발부 HW(하드웨어) 정규직/계약직 모집',
#   'company': '(주)싱크로직',
#   'career': '2 ~ 15년',
#   'education': '대학(2,3년)↑',
#   'employment_type': '정규직 · 계약직',
#   'workc_place': '경기 화성시',
#   'deadline': '~ 03/12',
#   'idx': '42294590',
#   'reg': '(3시간 전 등록)'},
#  {'title': 'IT서비스기획/Web/APP/사원~차장/ 환경가전 대기업',
#   'company': '오픈포지션',
#   'career': '4 ~ 17년',
#   'education': '대학교(4년)↑',
#   'employment_type': '정규직',
#   'workc_place': '서울 구로구',
#   'deadline': '~ 02/23',
#   'idx': '42294580',
#   'reg': '(3시간 전 등록)'},
#  {'title': '인프라운영관리/WAS클라우드/과차장/환경가전대기업',
#   'company': '오픈포지션',
#   'career': '8 ~ 16년',
#   'education': '대학교(4년)↑',
#   'employment_type': '정규직',
#   'workc_place': '서울 중구',
#   'deadline': '~ 02/23',
#   'idx': '42294567',
#   'reg': '(3시간 전 등록)'},
#  {'title': '[국내 메이져 화장품 회사] 플랫폼 백엔드 개발(3년)',
#   'company': '주) 석세스코리아컨설팅',
#   'career': '경력 3년↑',
#   'education': '대학교(4년)↑',
#   'employment_type': '정규직',
#   'workc_place': '서울 용산구',
#   'deadline': '~ 02/16',
#   'idx': '42294562',
#   'reg': '(3시간 전 등록)'},
#  {'title': 'WEB 기간계 시스템 운영,개발 /대리~차장/환경가전대기업',
#   'company': '오픈포지션',
#   'career': '4 ~ 16년',
#   'education': '대학교(4년)↑',
#   'employment_type': '정규직',
#   'workc_place': '서울 구로구',
#   'deadline': '~ 02/23',
#   'idx': '42294561',
#   'reg': '(3시간 전 등록)'},
#  {'title': '백엔드(Back-end)개발자채용(내일채움공제 가능)',
#   'company': '(주) 어디',
#   'career': '경력 1년↑',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '부산 해운대구',
#   'deadline': '~ 03/12',
#   'idx': '42294556',
#   'reg': '(3시간 전 등록)'},
#  {'title': '[원주] 22년 상반기 부문별 직원 공개채용',
#   'company': '(주)시야인사이트',
#   'career': '신입 · 경력',
#   'education': '대학(2,3년)↑',
#   'employment_type': '정규직',
#   'workc_place': '강원 원주시',
#   'deadline': '~ 02/28',
#   'idx': '42294552',
#   'reg': '(3시간 전 등록)'},
#  {'title': 'SAP ERP운영,관리,설계,개선/대리~차장/환경가전대기업',
#   'company': '오픈포지션',
#   'career': '4 ~ 16년',
#   'education': '대학(2,3년)↑',
#   'employment_type': '정규직',
#   'workc_place': '서울 구로구',
#   'deadline': '~ 02/23',
#   'idx': '42294546',
#   'reg': '(3시간 전 등록)'},
#  {'title': '문구 사무용품 전문회사 - 오픈마켓 관리 및 운영직원 모집공고',
#   'company': '㈜모든오피스',
#   'career': '경력무관',
#   'education': '고졸↑',
#   'employment_type': '정규직',
#   'workc_place': '서울 강남구',
#   'deadline': '~ 03/12',
#   'idx': '42294542',
#   'reg': '(3시간 전 등록)'},
#  {'title': 'IoT 플랫폼 개발/Backend API/대리차장/환경가전대기업',
#   'company': '오픈포지션',
#   'career': '4 ~ 15년',
#   'education': '대학교(4년)↑',
#   'employment_type': '정규직',
#   'workc_place': '서울 구로구',
#   'deadline': '~ 02/23',
#   'idx': '42294535',
#   'reg': '(3시간 전 등록)'},
#  {'title': '[국내 메이져 화장품 회사] 풀스택 개발자 (7년이상)',
#   'company': '주) 석세스코리아컨설팅',
#   'career': '경력 7년↑',
#   'education': '대학교(4년)↑',
#   'employment_type': '정규직',
#   'workc_place': '서울 용산구',
#   'deadline': '~ 02/16',
#   'idx': '42294529',
#   'reg': '(3시간 전 등록)'},
#  {'title': 'iOS Mobile APP개발/Object-C/Swift/대리~차장/환경가전대기업',
#   'company': '오픈포지션',
#   'career': '4 ~ 16년',
#   'education': '대학교(4년)↑',
#   'employment_type': '정규직',
#   'workc_place': '서울 구로구',
#   'deadline': '~ 02/23',
#   'idx': '42294515',
#   'reg': '(3시간 전 등록)'},
#  {'title': 'Android Mobile APP개발/Kotlin/RESTful API/환경가전대기업',
#   'company': '오픈포지션',
#   'career': '4 ~ 16년',
#   'education': '대학교(4년)↑',
#   'employment_type': '정규직',
#   'workc_place': '서울 구로구',
#   'deadline': '~ 02/23',
#   'idx': '42294504',
#   'reg': '(4시간 전 등록)'},
#  {'title': '이수그룹 IT회사 신입/경력직 채용',
#   'company': '(주)이수시스템',
#   'career': '신입 · 경력',
#   'education': '대학교(4년)↑',
#   'employment_type': '정규직 · 계약직',
#   'workc_place': '서울 서초구',
#   'deadline': '~ 02/28',
#   'idx': '42294498',
#   'reg': '(4시간 전 등록)'},
#  {'title': '[국내 메이져 화장품 회사] AI 검색 엔지니어(5년)',
#   'company': '주) 석세스코리아컨설팅',
#   'career': '경력 5년↑',
#   'education': '대학교(4년)↑',
#   'employment_type': '정규직',
#   'workc_place': '서울 용산구',
#   'deadline': '~ 02/16',
#   'idx': '42294491',
#   'reg': '(4시간 전 등록)'},
#  {'title': 'Back-end /플랫폼개발/웹/API 자바/Kotlin/환경가전대기업',
#   'company': '오픈포지션',
#   'career': '5 ~ 16년',
#   'education': '대학교(4년)↑',
#   'employment_type': '정규직',
#   'workc_place': '서울 구로구',
#   'deadline': '~ 02/23',
#   'idx': '42294485',
#   'reg': '(4시간 전 등록)'},
#  {'title': 'Front-end/플랫폼개발/vue.js /react 기반 SPA/환경가전대기업',
#   'company': '오픈포지션',
#   'career': '5 ~ 16년',
#   'education': '대학교(4년)↑',
#   'employment_type': '정규직',
#   'workc_place': '서울 구로구',
#   'deadline': '~ 02/23',
#   'idx': '42294470',
#   'reg': '(4시간 전 등록)'},
#  {'title': 'IT 비용분석 경력자 채용',
#   'company': '(주)메이븐앤컴퍼니',
#   'career': '경력 3년↑',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '경기 수원시 권선구',
#   'deadline': '~ 03/12',
#   'idx': '42294456',
#   'reg': '(4시간 전 등록)'},
#  {'title': '코스닥 상장 중견기업(여의도) Data Scientis',
#   'company': '(주)코리아휴먼리소시스',
#   'career': '4 ~ 9년',
#   'education': '대학교(4년)↑',
#   'employment_type': '정규직',
#   'workc_place': '경기 평택시',
#   'deadline': '~ 02/25',
#   'idx': '42294447',
#   'reg': '(4시간 전 등록)'},
#  {'title': '[마인성형외과] 웹디자이너  정규직 채용',
#   'company': '마인성형외과',
#   'career': '신입 · 경력',
#   'education': '대학(2,3년)↑',
#   'employment_type': '정규직',
#   'workc_place': '서울 강남구',
#   'deadline': '~ 03/04',
#   'idx': '42294446',
#   'reg': '(4시간 전 등록)'},
#  {'title': '[부산] KT 개통, AS · 네트워크 현장직 모집',
#   'company': '포코시스템(주)',
#   'career': '경력무관',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '부산 동구',
#   'deadline': '~ 03/12',
#   'idx': '42294442',
#   'reg': '(4시간 전 등록)'},
#  {'title': '[신입/경력]강사/학생용 소프트웨어 자바 개발자 모집',
#   'company': '(주)타임교육',
#   'career': '신입 · 경력',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '서울 강남구',
#   'deadline': '~ 03/12',
#   'idx': '42294440',
#   'reg': '(4시간 전 등록)'},
#  {'title': 'JAVA 웹개발자 신입/경력직 채용',
#   'company': '(주)제이랩',
#   'career': '신입 · 경력',
#   'education': '학력무관',
#   'employment_type': '정규직 · 계약직',
#   'workc_place': '서울 송파구',
#   'deadline': '~ 04/11',
#   'idx': '42294437',
#   'reg': '(4시간 전 등록)'},
#  {'title': 'Web Front-End 개발자  모집-서비스/게임(신입 및 경력)',
#   'company': '㈜지니프릭스',
#   'career': '신입 · 경력',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '서울 금천구',
#   'deadline': '~ 02/28',
#   'idx': '42294378',
#   'reg': '(4시간 전 등록)'},
#  {'title': '서버 개발자 모집(신입 및 경력)',
#   'company': '㈜지니프릭스',
#   'career': '경력무관',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '서울 금천구',
#   'deadline': '~ 02/28',
#   'idx': '42294340',
#   'reg': '(4시간 전 등록)'},
#  {'title': '[워라밸 기업] 웹 개발자/서버 개발자 모집',
#   'company': '(주)엠에스벤터',
#   'career': '신입 · 경력',
#   'education': '학력무관',
#   'employment_type': '정규직 · 계약직',
#   'workc_place': '인천 연수구',
#   'deadline': '~ 02/28',
#   'idx': '42294332',
#   'reg': '(4시간 전 등록)'},
#  {'title': '신사업 기획전략 채용- 경력무관',
#   'company': '주식회사 리폴룩스',
#   'career': '경력무관',
# ...
#  {'title': '[샤픈고트] 웹디자이너 채용 공고',
#   'company': '(주)샤픈고트',
#   'career': '경력 1년↑',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '부산 해운대구',
#   'deadline': '내일마감',
#   'idx': '42288026',
#   'reg': '(23시간 전 등록)'},
#  {'title': '2022 상반기 백엔드/서버개발 경력직 채용',
#   'company': '(주)호호컴퍼니',
#   'career': '3 ~ 6년',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '전남 나주시',
#   'deadline': '채용시',
#   'idx': '42287996',
#   'reg': '(23시간 전 등록)'},
#  {'title': 'pharmaceutical Analytics Consultant( HIRA 데이터분석)',
#   'company': '코리아써치',
#   'career': '경력 3년↑',
#   'education': '대학교(4년)↑',
#   'employment_type': '정규직',
#   'workc_place': '서울 강남구',
#   'deadline': '~ 02/24',
#   'idx': '42287959',
#   'reg': '(23시간 전 등록)'},
#  {'title': '2022년 소프트웨어(SW) 개발 담당자(정규직) 모집',
#   'company': '(주)글림시스템즈',
#   'career': '경력무관',
#   'education': '대학(2,3년)↑',
#   'employment_type': '정규직',
#   'workc_place': '대전 유성구',
#   'deadline': '상시채용',
#   'idx': '42287949',
#   'reg': '(23시간 전 등록)'},
#  {'title': 'e-스포츠 전략 담당/세계적인 FPS게임사/영어/판교',
#   'company': '(주)에이치알비즈코리아',
#   'career': '5 ~ 12년',
#   'education': '대학교(4년)↑',
#   'employment_type': '정규직',
#   'workc_place': '경기 성남시 분당구',
#   'deadline': '~ 03/11',
#   'idx': '42287935',
#   'reg': '(23시간 전 등록)'},
#  {'title': '건설/안전 IT 서비스 기술영업',
#   'company': '(주)티앤블루랩',
#   'career': '경력무관',
#   'education': '대학(2,3년)↑',
#   'employment_type': '정규직',
#   'workc_place': '서울 금천구',
#   'deadline': '~ 03/11',
#   'idx': '42287925',
#   'reg': '(23시간 전 등록)'},
#  {'title': '[㈜루나소프트] AWS시스템엔지니어 경력직 채용',
#   'company': '(주)루나소프트',
#   'career': '경력 2년↑',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '서울 강남구',
#   'deadline': '채용시',
#   'idx': '42287924',
#   'reg': '(23시간 전 등록)'},
#  {'title': '(주)엔솔브 2022년 C# 개발자(정규직)채용',
#   'company': '(주)엔솔브',
#   'career': '경력무관',
#   'education': '대학(2,3년)↑',
#   'employment_type': '정규직',
#   'workc_place': '부산 북구',
#   'deadline': '~ 04/10',
#   'idx': '42287909',
#   'reg': '(23시간 전 등록)'},
#  {'title': '앞으로 함께할 웹(PHP)개발자를 찾습니다.',
#   'company': '디제이메디(주)',
#   'career': '경력 2년↑',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '경기 고양시 일산동구',
#   'deadline': '~ 03/11',
#   'idx': '42287902',
#   'reg': '(23시간 전 등록)'},
#  {'title': '기술영업 (산업용 카메라)',
#   'company': '㈜씽크론',
#   'career': '신입 · 경력',
#   'education': '대학교(4년)↑',
#   'employment_type': '정규직',
#   'workc_place': '서울 구로구',
#   'deadline': '~ 03/11',
#   'idx': '42287894',
#   'reg': '(23시간 전 등록)'},
#  {'title': '[외국계자동차부품사] xEV System software engineer',
#   'company': '(주)인핸스파트너스',
#   'career': '5 ~ 14년',
#   'education': '대학교(4년)↑',
#   'employment_type': '정규직',
#   'workc_place': '경기 용인시 기흥구',
#   'deadline': '~ 02/19',
#   'idx': '42287892',
#   'reg': '(23시간 전 등록)'},
#  {'title': '[(주)메가웍스] 직원(사업기획) 채용',
#   'company': '(주)메가웍스',
#   'career': '경력 2년↑',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '광주 동구',
#   'deadline': '~ 03/11',
#   'idx': '42287885',
#   'reg': '(23시간 전 등록)'},
#  {'title': '미디어팀  웹 개발자 채용 - 경력/신입',
#   'company': '(주)앨컴퍼니',
#   'career': '경력무관',
#   'education': '고졸↑',
#   'employment_type': '계약직',
#   'workc_place': '서울 강남구',
#   'deadline': '~ 03/11',
#   'idx': '42287877',
#   'reg': '(23시간 전 등록)'},
#  {'title': 'PHP 개발자 경력자 채용(연봉협의)',
#   'company': '아솜',
#   'career': '경력 2년↑',
#   'education': '고졸↑',
#   'employment_type': '정규직',
#   'workc_place': '서울 서초구',
#   'deadline': '~ 04/10',
#   'idx': '42287873',
#   'reg': '(23시간 전 등록)'},
#  {'title': '열정 가득한 웹디자이너 추가 모집합니다',
#   'company': '(주)반하나컨설팅',
#   'career': '1 ~ 2년',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '부산 부산진구',
#   'deadline': '~ 03/11',
#   'idx': '42287860',
#   'reg': '(23시간 전 등록)'},
#  {'title': '2022년  웹 UI 퍼블리셔 채용',
#   'company': '(주)에스제이테크놀로지',
#   'career': '경력 3년↑',
#   'education': '대학(2,3년)↑',
#   'employment_type': '정규직 · 계약직',
#   'workc_place': '서울 마포구',
#   'deadline': '~ 02/15',
#   'idx': '42287854',
#   'reg': '(23시간 전 등록)'},
#  {'title': 'QA엔지니어 (Web/App)채용 (정규직)',
#   'company': '미스터블루(주)',
#   'career': '2 ~ 3년',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '서울 마포구',
#   'deadline': '~ 03/11',
#   'idx': '42287852',
#   'reg': '(23시간 전 등록)'},
#  {'title': '[NH통합IT센터] Java, C# 정규직 채용 (초급개발자)',
#   'company': '(주)미네르바소프트',
#   'career': '경력무관',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '경기 의왕시',
#   'deadline': '~ 03/11',
#   'idx': '42287835',
#   'reg': '(23시간 전 등록)'},
#  {'title': '에이프로젠제약㈜ 영업지원/영업 및 전산 직원 채용',
#   'company': '에이프로젠제약(주)',
#   'career': '신입 · 경력',
#   'education': '고졸↑',
#   'employment_type': '정규직',
#   'workc_place': '경기 성남시 중원구',
#   'deadline': '~ 02/20',
#   'idx': '42287814',
#   'reg': '(23시간 전 등록)'},
#  {'title': '온라인 뷰티 컨텐츠 - 경력 디자이너 모집',
#   'company': '(주)피에이인터네셔널',
#   'career': '경력 3년↑',
#   'education': '대학(2,3년)↑',
#   'employment_type': '정규직',
#   'workc_place': '서울 마포구',
#   'deadline': '채용시',
#   'idx': '42287807',
#   'reg': '(23시간 전 등록)'},
#  {'title': 'SW/솔루션 경력직 채용',
#   'company': '(주)지존',
#   'career': '3 ~ 5년',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '서울전체',
#   'deadline': '상시채용',
#   'idx': '42287804',
#   'reg': '(23시간 전 등록)'},
#  {'title': '(주)한국비즈넷  사업본부 직원 채용 공고',
#   'company': '(주)한국비즈넷',
#   'career': '경력무관',
#   'education': '고졸↑',
#   'employment_type': '정규직',
#   'workc_place': '서울 구로구',
#   'deadline': '~ 03/11',
#   'idx': '42287802',
#   'reg': '(23시간 전 등록)'},
#  {'title': '[한국비즈넷] JAVA기반 물류 시스템 개발 시니어 인재 채용',
#   'company': '(주)한국비즈넷',
#   'career': '경력 7년↑',
#   'education': '대학(2,3년)↑',
#   'employment_type': '정규직',
#   'workc_place': '서울 구로구',
#   'deadline': '~ 03/11',
#   'idx': '42287787',
#   'reg': '(23시간 전 등록)'},
#  {'title': '(주)한국비즈넷 연구개발실 개발자 모집',
#   'company': '(주)한국비즈넷',
#   'career': '신입 · 경력',
#   'education': '대학(2,3년)↑',
#   'employment_type': '정규직',
#   'workc_place': '서울 구로구',
#   'deadline': '~ 03/11',
#   'idx': '42287782',
#   'reg': '(23시간 전 등록)'},
#  {'title': '안드로이드 개발자 ((주)립페이- 경산 근무)',
#   'company': '(주)엘엔벤처그룹',
#   'career': '3 ~ 7년',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '경북 경산시',
#   'deadline': '채용시',
#   'idx': '42287774',
#   'reg': '(23시간 전 등록)'},
#  {'title': '[(주)인젠트]R&D Center 서버개발자 신입/경력 채용',
#   'company': '(주)인젠트',
#   'career': '신입 · 경력',
#   'education': '대학교(4년)↑',
#   'employment_type': '정규직',
#   'workc_place': '서울 영등포구',
#   'deadline': '~ 03/31',
#   'idx': '42287772',
#   'reg': '(23시간 전 등록)'},
#  {'title': '웹개발, 반응형웹 정규직 모집(경력무관)',
#   'company': '(주)모비다임',
#   'career': '경력무관',
#   'education': '대학(2,3년)↑',
#   'employment_type': '정규직',
#   'workc_place': '대전 동구',
#   'deadline': '채용시',
#   'idx': '42287760',
#   'reg': '(23시간 전 등록)'},
#  {'title': '[원더피플]보안분석팀[Anti-Cheat] Data Analyst 모집',
#   'company': '(주)원더피플',
#   'career': '신입 · 경력',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '서울 강남구',
#   'deadline': '~ 04/10',
#   'idx': '42287755',
#   'reg': '(23시간 전 등록)'},
#  {'title': '마포 상암동 공기업 제니퍼 개발자 모집 ( 즉시출근 장기 SM )',
#   'company': '푸른IT',
#   'career': '4 ~ 15년',
#   'education': '대학(2,3년)↑',
#   'employment_type': '프리랜서',
#   'workc_place': '서울 마포구',
#   'deadline': '~ 02/18',
#   'idx': '42287740',
#   'reg': '(23시간 전 등록)'},
#  {'title': '기술부 신입사원모집',
#   'company': '(주)씨에스프론트라인',
#   'career': '신입',
#   'education': '고졸↑',
#   'employment_type': '정규직',
#   'workc_place': '경기 성남시 수정구',
#   'deadline': '~ 04/10',
#   'idx': '42287717',
#   'reg': '(23시간 전 등록)'},
#  {'title': '전산실 개발자 채용 - 신입 또는 경력 6년 이하',
#   'company': '디에이치(주)',
#   'career': '신입 · 경력',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '경기 수원시 권선구',
#   'deadline': '~ 03/07',
#   'idx': '42287700',
#   'reg': '(23시간 전 등록)'},
#  {'title': '네트워크, 보안, 서버 엔지니어 채용',
#   'company': '에스지에이강원(주)',
#   'career': '경력무관',
#   'education': '대학(2,3년)↑',
#   'employment_type': '정규직',
#   'workc_place': '강원 춘천시',
#   'deadline': '~ 03/11',
#   'idx': '42287632',
#   'reg': '(23시간 전 등록)'},
#  {'title': '[그린플랫폼] 웹퍼블리셔',
#   'company': '주식회사 그린플랫폼',
#   'career': '경력 1년↑',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '경기 과천시',
#   'deadline': '~ 03/11',
#   'idx': '42287631',
#   'reg': '(23시간 전 등록)'},
#  {'title': '우리동네 히어로의 개발자 히어로를 찾습니다.',
#   'company': '(주)우리동네히어로',
#   'career': '3 ~ 5년',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '서울 성동구',
#   'deadline': '~ 04/10',
#   'idx': '42287619',
#   'reg': '(23시간 전 등록)'},
#  {'title': '현대오일뱅크 채용 연계형 인턴 모집',
#   'company': '현대오일뱅크(주)',
#   'career': '신입',
#   'education': '대학교(4년)↑',
#   'employment_type': '인턴직',
#   'workc_place': '충남 서산시',
#   'deadline': '~ 02/23',
#   'idx': '42287618',
#   'reg': '(23시간 전 등록)'},
#  {'title': '[천안/아산] 노리시스템(주)  JAVA, C#.NET, DB 개발자 모집',
#   'company': '노리시스템(주)',
#   'career': '경력 3년↑',
#   'education': '대학(2,3년)↑',
#   'employment_type': '정규직',
#   'workc_place': '충남 천안시 서북구',
#   'deadline': '~ 02/28',
#   'idx': '42287605',
#   'reg': '(23시간 전 등록)'},
#  {'title': '[VR게임 개발업체] 서버 모집',
#   'company': '(주)스토익엔터테인먼트',
#   'career': '신입 · 경력',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '서울 마포구',
#   'deadline': '~ 03/11',
#   'idx': '42287597',
#   'reg': '(23시간 전 등록)'},
#  {'title': '주식회사 포데로사 각 부문 신입 및 경력 모집',
#   'company': '주식회사 포데로사',
#   'career': '경력무관',
#   'education': '학력무관',
#   'employment_type': '정규직 · 계약직',
#   'workc_place': '서울 서초구',
#   'deadline': '~ 02/28',
#   'idx': '42287562',
#   'reg': '(23시간 전 등록)'},
#  {'title': '[원더피플]보안분석팀 [Anti-Cheat] Reverse Engineer 모집',
#   'company': '(주)원더피플',
#   'career': '경력 3년↑',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '서울 강남구',
#   'deadline': '~ 04/10',
#   'idx': '42287559',
#   'reg': '(23시간 전 등록)'},
#  {'title': '기술연구소 Flutter/SQL/Android/Node.js 외 경력무관',
#   'company': '(주)삼일엘텍',
#   'career': '경력무관',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '경기 화성시',
#   'deadline': '~ 02/28',
#   'idx': '42287548',
#   'reg': '(23시간 전 등록)'},
#  {'title': '웹프로그램 경력직(7년이상, 팀장급)모집',
#   'company': '(주)오엠인터랙티브',
#   'career': '경력 7년↑',
#   'education': '학력무관',
#   'employment_type': '정규직 · 계약직',
#   'workc_place': '서울 성동구',
#   'deadline': '~ 03/11',
#   'idx': '42287544',
#   'reg': '(23시간 전 등록)'},
#  {'title': '[천안] 노리시스템(주) 시스템 운영자 모집',
#   'company': '노리시스템(주)',
#   'career': '신입',
#   'education': '대학(2,3년)↑',
#   'employment_type': '정규직',
#   'workc_place': '충남 천안시 서북구',
#   'deadline': '~ 02/28',
#   'idx': '42287524',
#   'reg': '(23시간 전 등록)'},
#  {'title': '[03개월] 퍼블리셔 모집',
#   'company': '(주)웹크루트',
#   'career': '경력 6년↑',
#   'education': '학력무관',
#   'employment_type': '프리랜서',
#   'workc_place': '서울 서초구',
#   'deadline': '~ 02/18',
#   'idx': '42287500',
#   'reg': '(23시간 전 등록)'},
#  {'title': '[홈체크] 백엔드 개발자 공고',
#   'company': '(주)케이엘',
#   'career': '신입 · 경력',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '경기전체',
#   'deadline': '상시채용',
#   'idx': '42287491',
#   'reg': '(23시간 전 등록)'},
#  {'title': '[자동차 사이버 보안]임베디드 리눅스 SW 개발자 모집',
#   'company': '(주)페스카로',
#   'career': '신입 · 경력',
#   'education': '대학교(4년)↑',
#   'employment_type': '정규직',
#   'workc_place': '경기 성남시 수정구',
#   'deadline': '~ 02/27',
#   'idx': '42287476',
#   'reg': '(23시간 전 등록)'},
#  {'title': '[정규직,야근無]하트게임즈 자바스크립트 게임 개발자 채용',
#   'company': '(주) 하트게임즈',
#   'career': '경력무관',
#   'education': '대학(2,3년)↑',
#   'employment_type': '정규직',
#   'workc_place': '서울 강남구',
#   'deadline': '~ 03/11',
#   'idx': '42287474',
#   'reg': '(23시간 전 등록)'},
#  {'title': '[선릉/연봉협의/소속전환]유명기업 IT분야(데이터기술) 영업지원',
#   'company': '템프인(주)',
#   'career': '경력무관',
#   'education': '대학(2,3년)↑',
#   'employment_type': '파견직',
#   'workc_place': '서울 강남구',
#   'deadline': '~ 03/11',
#   'idx': '42287452',
#   'reg': '(23시간 전 등록)'},
#  {'title': '해외/국내영업 경력직 채용공고',
#   'company': '㈜프랭클린테크놀로지',
#   'career': '경력무관',
#   'education': '대학교(4년)↑',
#   'employment_type': '정규직',
#   'workc_place': '서울 금천구',
#   'deadline': '~ 02/18',
#   'idx': '42287431',
#   'reg': '(23시간 전 등록)'},
#  {'title': '사업전략 기획 및 마케팅 경력 사원 모집',
#   'company': '㈜프랭클린테크놀로지',
#   'career': '경력무관',
#   'education': '대학교(4년)↑',
#   'employment_type': '정규직',
#   'workc_place': '서울 금천구',
#   'deadline': '~ 02/18',
#   'idx': '42287418',
#   'reg': '(23시간 전 등록)'},
#  {'title': '영상 작업 외 신입사원 채용 공고(정규직)',
#   'company': '세방산업',
#   'career': '경력무관',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '서울 광진구',
#   'deadline': '~ 04/10',
#   'idx': '42287407',
#   'reg': '(23시간 전 등록)'},
#  {'title': '[메쉬코리아(부릉)] QA Engineer (풀필먼트 담당) 채용',
#   'company': '(주)메쉬코리아',
#   'career': '3 ~ 6년',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '서울 강남구',
#   'deadline': '~ 03/11',
#   'idx': '42287402',
#   'reg': '(23시간 전 등록)'},
#  {'title': 'RPA, IT 경력자 모십니다.',
#   'company': '(주)위칸소프트',
#   'career': '경력 1년↑',
#   'education': '학력무관',
#   'employment_type': '정규직 · 계약직',
#   'workc_place': '서울 종로구',
#   'deadline': '~ 03/11',
#   'idx': '42287356',
#   'reg': '(23시간 전 등록)'},
#  {'title': '위츠.  22년 신입/경력사원 채용',
#   'company': '(주)위츠',
#   'career': '신입 · 경력',
#   'education': '고졸↑',
#   'employment_type': '정규직',
#   'workc_place': '경기 수원시 영통구',
#   'deadline': '~ 03/13',
#   'idx': '42287353',
#   'reg': '(23시간 전 등록)'},
#  {'title': '[신입] IT부문 개발자 신입사원 채용',
#   'company': '(주)비즈테크파트너스',
#   'career': '신입',
#   'education': '대학교(4년)↑',
#   'employment_type': '정규직 · 인턴직',
#   'workc_place': '서울 마포구',
#   'deadline': '~ 02/13',
#   'idx': '42287311',
#   'reg': '(23시간 전 등록)'},
#  {'title': '각 부문 경력/신입 채용',
#   'company': '알보젠코리아(주)',
#   'career': '신입 · 경력',
#   'education': '고졸↑',
#   'employment_type': '정규직 · 계약직',
#   'workc_place': '서울 영등포구',
#   'deadline': '~ 02/16',
#   'idx': '42287309',
#   'reg': '(23시간 전 등록)'},
#  {'title': '[마블러스] PM / 정부 R&D지원사업 기획자 모집',
#   'company': '마블러스',
#   'career': '신입 · 경력',
#   'education': '대학교(4년)↑',
#   'employment_type': '정규직',
#   'workc_place': '서울 강남구',
#   'deadline': '상시채용',
#   'idx': '42287293',
#   'reg': '(23시간 전 등록)'},
#  {'title': '[PG사] 2022년 (주)ILK 각 부문 인재 채용',
#   'company': '(주)이삭랜드코리아',
#   'career': '신입 · 경력',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '서울 마포구',
#   'deadline': '~ 02/28',
#   'idx': '42287286',
#   'reg': '(23시간 전 등록)'},
#  {'title': '2022년 윈하이텍 상반기 신입/경력직 채용',
#   'company': '(주)윈하이텍',
#   'career': '신입 · 경력',
#   'education': '대학(2,3년)↑',
#   'employment_type': '정규직',
#   'workc_place': '서울 금천구',
#   'deadline': '~ 03/11',
#   'idx': '42287271',
#   'reg': '(23시간 전 등록)'},
#  {'title': '코리아크레딧뷰로(주) 서비스운영 및 데이터분석 관련 업무 채용',
#   'company': '코리아크레딧뷰로(주)',
#   'career': '경력무관',
#   'education': '대학(2,3년)↑',
#   'employment_type': '계약직',
#   'workc_place': '서울 영등포구',
#   'deadline': '~ 02/21',
#   'idx': '42287270',
#   'reg': '(23시간 전 등록)'},
#  {'title': 'CJ ENM 엔터테인먼트부문광고 시스템 개발 경력 채용',
#   'company': '(주)씨제이이엔엠',
#   'career': '경력 3년↑',
#   'education': '대학교(4년)↑',
#   'employment_type': '정규직',
#   'workc_place': '서울 중구',
#   'deadline': '~ 02/27',
#   'idx': '42287256',
#   'reg': '(23시간 전 등록)'},
#  {'title': '[안진회계법인] 2022년 재무자문본부 경력직 통합 채용',
#   'company': '안진회계법인',
#   'career': '경력',
#   'education': '대학교(4년)↑',
#   'employment_type': '정규직',
#   'workc_place': '서울 영등포구',
#   'deadline': '~ 03/06',
#   'idx': '42287230',
#   'reg': '(23시간 전 등록)'},
#  {'title': '신입 Java 웹개발자 모집',
#   'company': '(주)에스에스비정보기술',
#   'career': '경력무관',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '서울 강남구',
#   'deadline': '~ 03/11',
#   'idx': '42287206',
#   'reg': '(23시간 전 등록)'},
#  {'title': '[KG그룹-KG ICT]SAP ERP 운영/개발자(CO, SD, MM, BC/EAI)채용',
#   'company': '케이지아이씨티(주)',
#   'career': '경력 3년↑',
#   'education': '대학교(4년)↑',
#   'employment_type': '정규직',
#   'workc_place': '서울 중구',
#   'deadline': '~ 02/28',
#   'idx': '42287137',
#   'reg': '(23시간 전 등록)'},
#  {'title': '금융권 (고객사상주) PC/주변기기 전산장비 유지보수 정규직',
#   'company': '(주)티오엠테크',
#   'career': '신입 · 경력',
#   'education': '대학(2,3년)↑',
#   'employment_type': '정규직',
#   'workc_place': '서울 구로구',
#   'deadline': '~ 03/11',
#   'idx': '42287135',
#   'reg': '(23시간 전 등록)'},
#  {'title': '웹 개발자 정규직 채용',
#   'company': '주식회사 테이크',
#   'career': '경력무관',
#   'education': '학력무관',
#   'employment_type': '정규직',
#   'workc_place': '서울 구로구',
#   'deadline': '~ 03/11',
#   'idx': '42287134',
#   'reg': '(23시간 전 등록)'},
#  {'title': "[VT코스메틱] '디자이너(웹/패키지/영상)' 경력사원 채용",
#   'company': '(주)브이티코스메틱',
#   'career': '1 ~ 6년',
#   'education': '대학(2,3년)↑',
#   'employment_type': '정규직',
#   'workc_place': '서울 강남구',
#   'deadline': '~ 03/11',
#   'idx': '42287097',
#   'reg': '(23시간 전 등록)'},
#  {'title': '영업팀 신입 및 경력사원을 모집 합니다.',
#   'company': '코위버(주)',
#   'career': '경력무관',
#   'education': '대학(2,3년)↑',
#   'employment_type': '정규직',
#   'workc_place': '서울 강서구',
#   'deadline': '채용시',
#   'idx': '42287081',
#   'reg': '(1일 전 등록)'}]

# %%
pd.DataFrame(data)
# Out:
#                                                  title     company   career  \
# 0                                    [O2pluss] AOS 개발자    (주)오투플러스  3 ~ 10년
# 1                              [O2pluss] 웹개발 프론트엔드 개발자    (주)오투플러스  3 ~ 10년
# 2                           [O2pluss] 웹개발 Back-end 개발자    (주)오투플러스  3 ~ 10년
# 3                                  모바일 백엔드 개발자 (3년 이상)   (주)닥터다이어리  3 ~ 10년
# 4                                  QA/테스터 계약직 채용(신입사원)     (주)큐아이즈       신입
# ..                                                 ...         ...      ...
# 681  [KG그룹-KG ICT]SAP ERP 운영/개발자(CO, SD, MM, BC/EAI)채용  케이지아이씨티(주)   경력 3년↑
# 682                  금융권 (고객사상주) PC/주변기기 전산장비 유지보수 정규직    (주)티오엠테크  신입 · 경력
# 683                                       웹 개발자 정규직 채용    주식회사 테이크     경력무관
# 684                  [VT코스메틱] '디자이너(웹/패키지/영상)' 경력사원 채용  (주)브이티코스메틱   1 ~ 6년
# 685                             영업팀 신입 및 경력사원을 모집 합니다.      코위버(주)     경력무관
#
#      education employment_type workc_place deadline       idx          reg
# 0         학력무관             정규직        경기전체     상시채용  42297836   (15분 전 등록)
# 1         학력무관             정규직        경기전체     상시채용  42297820   (16분 전 등록)
# 2         학력무관             정규직        경기전체     상시채용  42297790   (18분 전 등록)
# 3     대학교(4년)↑             정규직        서울전체     상시채용  42297740   (22분 전 등록)
# 4    대학(2,3년)↑             계약직      서울 서초구      채용시  42297718   (24분 전 등록)
# ..         ...             ...         ...      ...       ...          ...
# 681   대학교(4년)↑             정규직       서울 중구  ~ 02/28  42287137  (23시간 전 등록)
# 682  대학(2,3년)↑             정규직      서울 구로구  ~ 03/11  42287135  (23시간 전 등록)
# 683       학력무관             정규직      서울 구로구  ~ 03/11  42287134  (23시간 전 등록)
# 684  대학(2,3년)↑             정규직      서울 강남구  ~ 03/11  42287097  (23시간 전 등록)
# 685  대학(2,3년)↑             정규직      서울 강서구      채용시  42287081    (1일 전 등록)
#
# [686 rows x 9 columns]
