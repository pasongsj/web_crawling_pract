# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
URL = 'https://www.saramin.co.kr/zf_user/jobs/list/job-category?cat_mcls=2&sort=RD'
I_URL = 'https://www.saramin.co.kr/zf_user/jobs/relay/view?'
LIMIT = 1

# %%
def extract_info(info):#썸네일 세부 info
    global LIMIT
    #inx
    idx = info['id'][4:]
       
    #회사명
    company = info.find("div",{"class":"company_nm"}).find("a").string
    #제목
    title = info.find("div",{"class":"job_tit"}).find("a").string
    #스택
    works = []

    work_s = info.find("span",{"class":"job_sector"}).find_all("span")#span값

    for work in work_s:
        works.append(work.string)

    #경력
    career = info.find("p",{"class":"career"}).string
    #학력
    education = info.find("p",{"class":"education"}).string
    #근무형태
    employment_t = info.find("p",{"class":"employment_type"}).string
    #근무장소
    try:
        place = info.find("p",{"class":"work_place"}).string
    except Exception as e:
        place = "None"
    #마감일
    deadline_tmp = info.find("p",{"class": "deadlines"}).get_text()
    deadline = deadline_tmp[:deadline_tmp.find('(')]

    #등록일
    reg = info.find("span",{"class":"reg_date"}).string
    
    if(reg == '(1일 전 등록)'):
        LIMIT = 0
        return {'title':title, 'company':company, 'career':career, 'education':education,
                'employment_type' :employment_t,  'workc_place':place, 'deadline': deadline,
                'idx':idx}

    return {'title':title, 'company':company, 'career':career, 'education':education,
                'employment_type' :employment_t,  'workc_place':place, 'deadline': deadline,
                'idx':idx}

# %%
def extract_page(pages):#썸네일 페이지 열기
    result = requests.get(f"{URL}&page={pages}")

    soup = BeautifulSoup(result.text, "html.parser")
    #print(soup)
    infos= soup.find_all("div", {"class":"list_item"})
    
    jobs = []
    for info in infos:
        job = extract_info(info)
        jobs.extend(job)
        if(LIMIT == 0):
            return jobs

    return jobs

# %%
def main():
    global LIMIT
    a_jobs = []
    i = 13
    while(LIMIT):
        a_jobs.append(extract_page(i))
        i = i+1
    return a_jobs

# %%
data = main()
data
# Out:
# (22시간 전 등록)
# (22시간 전 등록)
# (22시간 전 등록)
# (22시간 전 등록)
# (22시간 전 등록)
# (22시간 전 등록)
# (22시간 전 등록)
# (22시간 전 등록)
# (22시간 전 등록)
# (22시간 전 등록)
# (22시간 전 등록)
# (22시간 전 등록)
# (22시간 전 등록)
# (22시간 전 등록)
# (22시간 전 등록)
# (22시간 전 등록)
# (22시간 전 등록)
# (22시간 전 등록)
# (22시간 전 등록)
# (23시간 전 등록)
# (23시간 전 등록)
# (23시간 전 등록)
# (23시간 전 등록)
# (23시간 전 등록)
# (23시간 전 등록)
# (23시간 전 등록)
# (23시간 전 등록)
# (23시간 전 등록)
# (23시간 전 등록)
# (23시간 전 등록)
# (23시간 전 등록)
# (23시간 전 등록)
# (23시간 전 등록)
# (23시간 전 등록)
# (23시간 전 등록)
# (23시간 전 등록)
# (23시간 전 등록)
# (23시간 전 등록)
# (23시간 전 등록)
# (23시간 전 등록)
# (23시간 전 등록)
# (23시간 전 등록)
# (23시간 전 등록)
# (23시간 전 등록)
# (23시간 전 등록)
# (23시간 전 등록)
# (23시간 전 등록)
# (23시간 전 등록)
# (23시간 전 등록)
# (23시간 전 등록)
# (23시간 전 등록)
# (23시간 전 등록)
# (23시간 전 등록)
# (23시간 전 등록)
# (23시간 전 등록)
# (23시간 전 등록)
# (23시간 전 등록)
# (23시간 전 등록)
# (23시간 전 등록)
# (23시간 전 등록)
# (23시간 전 등록)
# (23시간 전 등록)
# (23시간 전 등록)
# (23시간 전 등록)
# (23시간 전 등록)
# (23시간 전 등록)
# (23시간 전 등록)
# (23시간 전 등록)
# (23시간 전 등록)
# (23시간 전 등록)
# (23시간 전 등록)
# (23시간 전 등록)
# (23시간 전 등록)
# (23시간 전 등록)
# (23시간 전 등록)
# (23시간 전 등록)
# (23시간 전 등록)
# (23시간 전 등록)
# (23시간 전 등록)
# (23시간 전 등록)
# (23시간 전 등록)
# (1일 전 등록)
# [['title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx'],
#  ['title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx',
#   'title',
#   'company',
#   'career',
#   'education',
#   'employment_type',
#   'workc_place',
#   'deadline',
#   'idx']]

# %%
pd.DataFrame(data)
# Out:
#      0        1       2          3                4            5         6    \
# 0  title  company  career  education  employment_type  workc_place  deadline
# 1  title  company  career  education  employment_type  workc_place  deadline
#
#    7      8        9    ...       390   391    392      393     394  \
# 0  idx  title  company  ...  deadline   idx  title  company  career
# 1  idx  title  company  ...      None  None   None     None    None
#
#          395              396          397       398   399
# 0  education  employment_type  workc_place  deadline   idx
# 1       None             None         None      None  None
#
# [2 rows x 400 columns]
